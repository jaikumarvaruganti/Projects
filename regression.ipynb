# %%
import pandas as pd
# import seaborn as sns
# import matplotlib.pyplot as plt
# from sklearn.linear_model import LogisticRegression

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1a0bae8a-a231-4760-84ee-074921854f08" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a0bae8a-a231-4760-84ee-074921854f08">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data= pd.read_csv('Insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.shape[1]
# Out:
# 7

# %%
for i in range(data.shape[1]):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6

# %%
for i in range(data.shape[1]):
  print(data.iloc[:,i].unique())
  print(data.iloc[:,i].value_counts())
# Out:
# [19 18 28 33 32 31 46 37 60 25 62 23 56 27 52 30 34 59 63 55 22 26 35 24
#  41 38 36 21 48 40 58 53 43 64 20 61 44 57 29 45 54 49 47 51 42 50 39]
# age
# 18    69
# 19    68
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
# ['female' 'male']
# sex
# male      676
# female    662
# Name: count, dtype: int64
# [27.9   33.77  33.    22.705 28.88  25.74  33.44  27.74  29.83  25.84
#  26.22  26.29  34.4   39.82  42.13  24.6   30.78  23.845 40.3   35.3
#  36.005 32.4   34.1   31.92  28.025 27.72  23.085 32.775 17.385 36.3
# ...

# %%
num_duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 1

# %%
data[data.duplicated()]
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
data_cleaned=data.drop_duplicates()

# %%
data.drop_duplicates(inplace=True)

# %%
num_duplicates = data.duplicated().sum()
print(f"Number of duplicate rows: {num_duplicates}")
# Out:
# Number of duplicate rows: 0

# %%
for i in data.select_dtypes(include=["object","int64"]).columns:
  print(data[i].value_counts())
  print("***"*5)
# Out:
# age
# 18    69
# 19    67
# 50    29
# 51    29
# 47    29
# 46    29
# 45    29
# 20    29
# 48    29
# 52    29
# 22    28
# 49    28
# 54    28
# 53    28
# 21    28
# 26    28
# 24    28
# 25    28
# 28    28
# 27    28
# 23    28
# 43    27
# 29    27
# 30    27
# 41    27
# 42    27
# 44    27
# 31    27
# 40    27
# 32    26
# 33    26
# 56    26
# 34    26
# 55    26
# 57    26
# 37    25
# 59    25
# 58    25
# 36    25
# 38    25
# 35    25
# 39    25
# 61    23
# 60    23
# 63    23
# 62    23
# 64    22
# Name: count, dtype: int64
# ***************
# sex
# male      675
# female    662
# Name: count, dtype: int64
# ***************
# children
# 0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: count, dtype: int64
# ***************
# smoker
# no     1063
# yes     274
# Name: count, dtype: int64
# ***************
# region
# southeast    364
# southwest    325
# northwest    324
# northeast    324
# Name: count, dtype: int64
# ***************

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.663452     1.095737  13279.121487
# std      14.044333     6.100468     1.205571  12110.359656
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.290000     0.000000   4746.344000
# 50%      39.000000    30.400000     1.000000   9386.161300
# 75%      51.000000    34.700000     2.000000  16657.717450
# max      64.000000    53.130000     5.000000  63770.428010

# %%
X=data.drop(['charges'],axis=1)

print(X)
y = data['charges']
print(y)
# Out:
#       age     sex     bmi  children smoker     region
# 0      19  female  27.900         0    yes  southwest
# 1      18    male  33.770         1     no  southeast
# 2      28    male  33.000         3     no  southeast
# 3      33    male  22.705         0     no  northwest
# 4      32    male  28.880         0     no  northwest
# ...   ...     ...     ...       ...    ...        ...
# 1333   50    male  30.970         3     no  northwest
# 1334   18  female  31.920         0     no  northeast
# 1335   18  female  36.850         0     no  southeast
# 1336   21  female  25.800         0     no  southwest
# 1337   61  female  29.070         0    yes  northwest
#
# [1337 rows x 6 columns]
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1337, dtype: float64

# %%
X=pd.get_dummies(X, dtype='int', drop_first=True)
print(X)
# Out:
#       age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 0      19  27.900         0         0           1                 0
# 1      18  33.770         1         1           0                 0
# 2      28  33.000         3         1           0                 0
# 3      33  22.705         0         1           0                 1
# 4      32  28.880         0         1           0                 1
# ...   ...     ...       ...       ...         ...               ...
# 1333   50  30.970         3         1           0                 1
# 1334   18  31.920         0         0           0                 0
# 1335   18  36.850         0         0           0                 0
# 1336   21  25.800         0         0           0                 0
# 1337   61  29.070         0         0           1                 1
#
#       region_southeast  region_southwest
# 0                    0                 1
# 1                    1                 0
# ...

# %%
X. info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1337 non-null   int64
#  1   bmi               1337 non-null   float64
#  2   children          1337 non-null   int64
#  3   sex_male          1337 non-null   int64
#  4   smoker_yes        1337 non-null   int64
#  5   region_northwest  1337 non-null   int64
#  6   region_southeast  1337 non-null   int64
#  7   region_southwest  1337 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 94.0 KB

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **box plot**

# %%
selected_columns = ['age', 'bmi', 'charges']
for col in selected_columns:
    plt.figure(figsize=(4, 4))
    sns.boxplot(x=data[col])
    plt.title(f'Box Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your data is in a DataFrame called 'df'
# Replace 'df' with the actual name of your DataFrame
selected_columns = ['age', 'bmi', 'charges']

plt.figure(figsize=(6, 6))
plt.boxplot(
    [data[col] for col in selected_columns],  # Access the actual data from the DataFrame
    labels=selected_columns,
    widths=0.7,
    patch_artist=True
)
plt.ylabel('Frequency')
plt.title('Box Plot')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# pair plot

# %%
sns.pairplot(data=data)
plt.show()

# %% [markdown]
# **scatter** **plot**

# %%
# Scatter Plot for Age vs. Charges
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['age'], y=data['charges'], hue=data['smoker'], palette='coolwarm')
plt.title('Scatter Plot of Age vs. Charges')
plt.xlabel('Age')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# Scatter Plot for BMI vs. Charges
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['bmi'], y=data['charges'], hue=data['smoker'], palette='coolwarm')
plt.title('Scatter Plot of BMI vs. Charges')
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.grid(True)
plt.show()

# Scatter Plot for Age vs. BMI
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data['age'], y=data['bmi'], hue=data['smoker'], palette='coolwarm')
plt.title('Scatter Plot of Age vs. BMI')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.grid(True)
plt.show()

# %% [markdown]
# **histogram**

# %%
# Histogram for Age
plt.figure(figsize=(10, 6))
plt.hist(data['age'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram for BMI
plt.figure(figsize=(10, 6))
plt.hist(data['bmi'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# Histogram for Charges
plt.figure(figsize=(10, 6))
plt.hist(data['charges'], bins=20, color='salmon', edgecolor='black')
plt.title('Distribution of Charges')
plt.xlabel('Charges')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# **bar** **plot**

# %%
sex_smoker_counts = data.groupby(['sex', 'smoker']).size().unstack()
sex_smoker_counts.plot(kind='bar', stacked=True, color=['lightgreen', 'yellow'])
plt.title('Count of Sex and Smoker Status')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
region_smoker_counts = data.groupby(['region', 'smoker']).size().unstack()
region_smoker_counts.plot(kind='bar', stacked=False, color=['red', 'blue'])
plt.title('Count of region and Smoker Status')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %%
# Bar Plot for Sex
plt.figure(figsize=(8, 6))
data['sex'].value_counts().plot(kind='bar', color=['skyblue', 'lightcoral'])
plt.title('Count of Sex')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Bar Plot for Smoker
plt.figure(figsize=(8, 6))
data['smoker'].value_counts().plot(kind='bar', color=['lightgreen', 'salmon'])
plt.title('Count of Smoker')
plt.xlabel('Smoker')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# Bar Plot for Region
plt.figure(figsize=(8, 6))
data['region'].value_counts().plot(kind='bar', color='lightblue')
plt.title('Count of Region')
plt.xlabel('Region')
plt.ylabel('Count')
plt.grid(True)
plt.show()

# %% [markdown]
# **pie** **chart**

# %%
# Pie Chart for Smoker
plt.figure(figsize=(6, 6))
data['smoker'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightgreen', 'salmon'])
plt.title('Proportion of Smokers vs. Non-Smokers')
plt.ylabel('')
plt.show()

# Pie Chart for Region
plt.figure(figsize=(6,6))
data['region'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow'])
plt.title('Proportion of Each Region')
plt.ylabel('')
plt.show()

plt.figure(figsize=(6,6))
data['children'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightblue', 'lightgreen', 'lightcoral', 'lightyellow','red'])
plt.ylabel('')
plt.show()

# %% [markdown]
# **correlation** **matrix**

# %%
plt.figure(figsize=(6, 4))
correlation_matrix = data[['age', 'bmi', 'charges']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
problematic_columns = ['sex_male', 'sex_female', 'region_northeast', 'region_northwest', 'region_southeast', 'region_southwest','smoker_yes','smoker_no']
existing_problematic_columns = [col for col in problematic_columns if col in data.columns]


if not existing_problematic_columns:
    data = pd.get_dummies(data, columns=['sex', 'region','smoker'], prefix=['sex', 'region','smoker'])

# Now calculate the correlation matrix with the newly created or existing columns
plt.figure(figsize=(6,6))  # Increased figure size for better visibility
correlation_matrix = data[['age', 'bmi', 'charges', 'children'] + existing_problematic_columns].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# linear regression

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np

# allow plots to appear directly in the notebook
# %matplotlib inline

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1337 non-null   int64
#  1   bmi               1337 non-null   float64
#  2   children          1337 non-null   int64
#  3   sex_male          1337 non-null   int64
#  4   smoker_yes        1337 non-null   int64
#  5   region_northwest  1337 non-null   int64
#  6   region_southeast  1337 non-null   int64
#  7   region_southwest  1337 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 94.0 KB

# %%
X.head()
# Out:
#    age     bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.900         0         0           1                 0
# 1   18  33.770         1         1           0                 0
# 2   28  33.000         3         1           0                 0
# 3   33  22.705         0         1           0                 1
# 4   32  28.880         0         1           0                 1
#
#    region_southeast  region_southwest
# 0                 0                 1
# 1                 1                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1337 entries, 0 to 1337
# Series name: charges
# Non-Null Count  Dtype
# --------------  -----
# 1337 non-null   float64
# dtypes: float64(1)
# memory usage: 20.9 KB

# %%
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.20, train_size=0.80,random_state=1)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.25, train_size=0.75,random_state=1)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.30, train_size=0.70,random_state=1)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size=0.40, train_size=0.60,random_state=1)

# %%
#X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.20, train_size=0.80)
lm2 = LinearRegression()
lm2.fit(X_train1, y_train1)
y_pred1 = lm2.predict(X_test1)
print(np.sqrt(metrics.mean_squared_error(y_test1, y_pred1)))
print((metrics.r2_score(y_test1, y_pred1)))
print((metrics.mean_squared_error(y_test1, y_pred1)))
print((metrics.mean_absolute_error(y_test1,y_pred1)))
# Out:
# 5689.30829118911
# 0.7497814388540698
# 32368228.832193147
# 3924.6360380217848

# %%
#X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.25, train_size=0.75)
lm2 = LinearRegression()
lm2.fit(X_train2, y_train2)
y_pred2 = lm2.predict(X_test2)
print(np.sqrt(metrics.mean_squared_error(y_test2, y_pred2)))
print((metrics.r2_score(y_test2, y_pred2)))
print((metrics.mean_squared_error(y_test2, y_pred2)))
print((metrics.mean_absolute_error(y_test2,y_pred2)))
# Out:
# 5992.503495873213
# 0.7200784016998649
# 35910098.148052685
# 4151.7215200297605

# %%
#X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.30, train_size=0.70)
lm2 = LinearRegression()
lm2.fit(X_train3, y_train3)
y_pred3 = lm2.predict(X_test3)
print(np.sqrt(metrics.mean_squared_error(y_test3, y_pred3)))
print((metrics.r2_score(y_test3, y_pred3)))
print((metrics.mean_squared_error(y_test3, y_pred3)))
print((metrics.mean_absolute_error(y_test3,y_pred3)))
# Out:
# 6043.804783305154
# 0.733326836658079
# 36527576.25870226
# 4207.799065841042

# %%
#X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size=0.40, train_size=0.60)
lm2 = LinearRegression()
lm2.fit(X_train4, y_train4)
y_pred4 = lm2.predict(X_test4)
print(np.sqrt(metrics.mean_squared_error(y_test4, y_pred4)))
print((metrics.r2_score(y_test4, y_pred4)))
print((metrics.mean_squared_error(y_test4, y_pred4)))
print((metrics.mean_absolute_error(y_test4,y_pred4)))
# Out:
# 6119.716442233048
# 0.7196282704835242
# 37450929.333337516
# 4274.286033572359

# %% [markdown]
# **KNN**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# 80-20

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train1,y_train1)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = model.predict(X_test1)
print(y_pred1)
# Out:
# [16820.517086  18192.71901   10971.66693   10336.797548  18179.196618
#   7182.362988   9037.28354   21986.61754   14312.35928   21926.88825
#  18610.132964   6827.35397   15732.260012   8312.86098    1372.48868
#  16637.80268    7331.625542  21151.78429   19167.73447   25937.297052
#   4004.50979   29370.532788  18494.878844  14322.47749    7459.11708
#  22671.025772  15867.571668  19609.90401    4940.15816    3823.70073
#  24846.90293    3985.0733    10633.271286  25803.835716  12007.3807
#   1561.134     31942.651644  19261.559494  14222.811394  15832.178256
#  14240.17668    8291.637436  10355.2936    17902.479582  36689.978988
#  12689.87445   32336.702692   7685.46873   11912.66588   11544.03559
#  22747.741916  11633.36595   19818.911902  13898.827284  14108.608092
#   6936.701148   7810.67289   11962.15698   11237.86892   33916.08512
#  13534.861874  21308.474918  11393.717402  10578.2225     6427.785372
#   7101.239332   2156.71866   21653.67231   13513.176664  15605.871344
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1})
print(df)
# Out:
#          Predicted       Actual
# 629   16820.517086  42983.45850
# 1087  18192.719010  11353.22760
# 283   10971.666930  11879.10405
# 790   10336.797548   5662.22500
# 594   18179.196618   5709.16440
# ...            ...          ...
# 1164   6854.735710   7153.55390
# 962   24152.910392  14474.67500
# 1158   8199.234850   2459.72010
# 1241  14537.414610  49577.66240
# 216   16690.005556  10355.64100
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred1)
# Out:
# 0.16403910584448667

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test1,y_pred1)
# Out:
# 7452.4967916171645

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1,y_pred1)
# Out:
# 108139753.47340277

# %%
mse = mean_squared_error(y_test1, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# 10399.026563741569

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test1, y_pred1)
print(mape)
mape = mape * 100
mape
# Out:
# 1.021303795431673
# 102.13037954316731

# %% [markdown]
# 75-25

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train2,y_train2)
# Out:
# KNeighborsRegressor()

# %%
y_pred2 = model.predict(X_test2)
print(y_pred2)
# Out:
# [16820.517086  18192.71901   10971.66693   10336.797548  18179.196618
#   9875.366438   9037.28354   21986.61754   14312.35928   21926.88825
#  18432.689714   6827.35397   15732.260012   8312.86098    7950.54881
#  16637.80268    7087.627102  21151.78429   19049.45909   25937.297052
#   4004.50979   29370.532788  15058.50808   14322.47749    7364.4263
#  22671.025772  15867.571668  19609.90401    4975.14435    3823.70073
#  32094.14139    3985.0733    10633.271286  25803.835716  12109.13934
#   1493.93174   31942.651644  19510.039404  14222.811394  14470.188534
#  14240.17668    8291.637436  10355.2936    17902.479582  36689.978988
#  12872.33582   32336.702692   5907.97738   11912.66588   11544.03559
#  28940.837676  11633.36595   19818.911902  13898.827284  14108.608092
#   7034.659608   5800.938214  11981.44765   11237.86892   33916.08512
#  13534.861874  21308.474918  11393.717402  10578.2225     6427.785372
#  10005.126852   2156.71866   21653.67231   13513.176664  15605.871344
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2})
print(df)
# Out:
#          Predicted       Actual
# 629   16820.517086  42983.45850
# 1087  18192.719010  11353.22760
# 283   10971.666930  11879.10405
# 790   10336.797548   5662.22500
# 594   18179.196618   5709.16440
# ...            ...          ...
# 954   14002.146050  20009.63365
# 1038   2309.642870   2250.83520
# 1264  19489.542028  10370.91255
# 375    9039.399876  18033.96790
# 798   11981.447650  11848.14100
#
# [335 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred2)
# Out:
# 0.1604538576814668

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test2,y_pred2)
# Out:
# 7430.074334183284

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test2,y_pred2)
# Out:
# 107702244.31968382

# %%
mse = mean_squared_error(y_test2, y_pred2)
rmse = np.sqrt(mse)
rmse
# Out:
# 10377.969180898728

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test2, y_pred2)
print(mape)
mape = mape * 100
mape
# Out:
# 0.9922207604320912
# 99.22207604320911

# %% [markdown]
# 70-30

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train3,y_train3)
# Out:
# KNeighborsRegressor()

# %%
y_pred3 = model.predict(X_test3)
print(y_pred3)
# Out:
# [16820.517086  18192.71901   10906.22358   10336.797548  18179.196618
#   9875.366438   9037.28354   21986.61754   14312.35928   21926.88825
#  18590.489714   6827.35397   13114.722442   8312.86098    7950.54881
#  16637.80268   11564.332778  29134.747464  19049.45909   25937.297052
#   4059.72193   36689.978988  15058.50808   14322.47749    7364.4263
#  22671.025772  10698.26192   19609.90401    4975.14435    3823.70073
#  32094.14139    3985.0733    10652.147846  25803.835716  12108.69037
#   1570.76804   38810.387854  19123.904964  14222.811394   9051.570386
#  14240.17668    8291.637436  10206.30944   17902.479582  36689.978988
#  12872.33582   32336.702692   5907.97738   11457.74596   11544.03559
#  28940.837676  11799.14819   19704.096342  13898.827284  14108.608092
#   7034.659608   5800.938214  11981.44765   11237.86892   33916.08512
#  13534.861874  21115.691808  11393.717402  10578.2225     6427.785372
#  10005.126852   1840.05641   21653.67231   13513.176664  15605.871344
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3})
print(df)
# Out:
#          Predicted       Actual
# 629   16820.517086  42983.45850
# 1087  18192.719010  11353.22760
# 283   10906.223580  11879.10405
# 790   10336.797548   5662.22500
# 594   18179.196618   5709.16440
# ...            ...          ...
# 924   17568.319604   6250.43500
# 873   23153.649520   6849.02600
# 731   12443.589620  10065.41300
# 363    2329.710530   2597.77900
# 10     2702.134300   2721.32080
#
# [402 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred3)
# Out:
# 0.12587000976715457

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test3,y_pred3)
# Out:
# 7821.080405679602

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test3,y_pred3)
# Out:
# 119734020.01951487

# %%
mse = mean_squared_error(y_test3, y_pred3)
rmse = np.sqrt(mse)
rmse
# Out:
# 10942.30414581476

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test3, y_pred3)
print(mape)
mape = mape * 100
mape
# Out:
# 0.9931559306144213
# 99.31559306144213

# %% [markdown]
# 60-40

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train4,y_train4)
# Out:
# KNeighborsRegressor()

# %%
y_pred4 = model.predict(X_test4)
print(y_pred4)
# Out:
# [16625.638896  18063.93172   11175.37467   10531.312918  18179.196618
#   9915.656948  22834.47852   17363.459026  14293.56623   21926.88825
#  18474.362314   9381.87708   13114.722442   8312.86098    7950.54881
#  16637.80268   11564.332778  29134.747464  19049.45909   25937.297052
#   4059.72193   36689.978988  14960.31054   20705.8929     7304.4811
#  30018.234972  10698.26192   19609.90401    5102.25984    3645.59461
#  32094.14139    7138.14262    8200.13632   25803.835716  12108.69037
#   1570.76804   38810.387854  22279.384374  14222.811394   9051.570386
#  14240.17668    8291.637436  10206.30944   17902.479582  36689.978988
#  16099.86868   32336.702692   8447.39685   11457.74596   11371.91754
#  28940.837676  11799.14819   20065.632952  13801.333084  13882.045052
#   9674.883768   8977.348316  11808.17205    7990.24672   33916.08512
#  13465.667474  23039.352316  11256.392782  10692.57305    6427.785372
#  10084.618482   1840.05641   21948.84106   13513.176664  15901.695614
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4})
print(df)
# Out:
#          Predicted       Actual
# 629   16625.638896  42983.45850
# 1087  18063.931720  11353.22760
# 283   11175.374670  11879.10405
# 790   10531.312918   5662.22500
# 594   18179.196618   5709.16440
# ...            ...          ...
# 479   10250.706446   1824.28540
# 538    8311.005520   8233.09750
# 117    7292.871730  19107.77960
# 5      6841.857110   3756.62160
# 1250   9183.408876  18648.42170
#
# [535 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred4)
# Out:
# 0.07810929819041912

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test4,y_pred4)
# Out:
# 7949.707449669534

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test4,y_pred4)
# Out:
# 123142456.57389885

# %%
mse = mean_squared_error(y_test4, y_pred4)
rmse = np.sqrt(mse)
rmse
# Out:
# 11096.957086242104

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test4, y_pred4)
print(mape)
mape = mape * 100
mape
# Out:
# 1.0242283715671563
# 102.42283715671563

# %% [markdown]
# **Support Vector Machine**

# %%
from sklearn.svm import SVR

# %% [markdown]
# 80-20

# %%
model = SVR(kernel='rbf')
model.fit(X_train1, y_train1)
# Out:
# SVR()

# %%
y_pred1 = model.predict(X_test1)
print(y_pred1)
# Out:
# [9557.36283478 9623.37438268 9614.44584998 9530.91191506 9540.96051076
#  9457.47775906 9449.81471916 9610.52989882 9617.95461902 9594.99472021
#  9631.55493168 9516.48953317 9602.87109233 9556.90183299 9441.00932203
#  9642.67591167 9490.8915501  9485.2060371  9624.30429591 9646.98682435
#  9487.23023278 9637.26239626 9563.85196072 9548.76350184 9474.4928276
#  9551.39095643 9546.42669573 9632.93405303 9496.23319828 9476.96033165
#  9585.23060459 9481.64291506 9468.55776567 9589.57118653 9439.25031433
#  9445.95335334 9481.06715618 9635.78961276 9511.40856751 9536.00137726
#  9598.77461464 9443.92340724 9586.37287922 9582.55780075 9637.67808823
#  9634.58492885 9595.07951433 9505.89551774 9584.81594366 9618.41263365
#  9639.72670301 9613.28113717 9613.35306657 9501.47714703 9575.82243821
#  9454.22477419 9450.77474553 9628.31783696 9496.41608895 9650.26398852
#  9605.42552873 9619.08769011 9445.9204455  9468.60277309 9465.43394305
# ...

# %%
df = pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1})
print(df)
# Out:
#         Predicted       Actual
# 629   9557.362835  42983.45850
# 1087  9623.374383  11353.22760
# 283   9614.445850  11879.10405
# 790   9530.911915   5662.22500
# 594   9540.960511   5709.16440
# ...           ...          ...
# 1164  9535.245712   7153.55390
# 962   9647.251845  14474.67500
# 1158  9443.216976   2459.72010
# 1241  9650.170529  49577.66240
# 216   9601.532432  10355.64100
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1,y_pred1)
# Out:
# -0.037880557580482144

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test1,y_pred1)
# Out:
# 7409.859428577142

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1,y_pred1)
# Out:
# 134260045.43546498

# %%
mse = mean_squared_error(y_test1, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# 11587.063710684644

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test1, y_pred1)
print(mape)
mape = mape * 100
mape
# Out:
# 1.1238741004370645
# 112.38741004370645

# %% [markdown]
# 75-25

# %%
model = SVR(kernel='rbf')
model.fit(X_train2, y_train2)
# Out:
# SVR()

# %%
y_pred2 = model.predict(X_test2)
print(y_pred2)
# Out:
# [9533.37347271 9595.47115478 9587.08906091 9508.40003269 9517.89436471
#  9438.35197511 9431.27074491 9583.35380399 9590.31291541 9568.72701949
#  9603.08665196 9494.47675634 9576.19482611 9532.81072477 9422.76380341
#  9613.54605665 9470.20925796 9465.01547712 9596.33139521 9617.56867358
#  9466.87911309 9608.40473773 9539.41408771 9525.21392969 9454.79451525
#  9527.73023543 9522.94154757 9604.42685414 9475.36891565 9457.01421785
#  9559.61365893 9461.49876341 9449.01984314 9563.61647472 9421.02218514
#  9427.54345015 9461.09768961 9607.05982181 9489.94312282 9513.10348599
#  9572.26200948 9425.27171485 9560.64198193 9557.08512324 9608.80455714
#  9605.96570226 9568.88906148 9484.39896677 9559.04780937 9590.74851943
#  9610.78948834 9585.97727023 9586.0523993  9480.52734359 9550.71714265
#  9435.23065764 9432.05495665 9600.1086102  9475.55015734 9620.63372624
#  9578.62210009 9591.41972407 9427.45446452 9448.99481969 9446.13155111
# ...

# %%
df = pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2})
print(df)
# Out:
#         Predicted       Actual
# 629   9533.373473  42983.45850
# 1087  9595.471155  11353.22760
# 283   9587.089061  11879.10405
# 790   9508.400033   5662.22500
# 594   9517.894365   5709.16440
# ...           ...          ...
# 954   9475.954900  20009.63365
# 1038  9429.359895   2250.83520
# 1264  9557.910487  10370.91255
# 375   9432.307463  18033.96790
# 798   9600.030665  11848.14100
#
# [335 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2,y_pred2)
# Out:
# -0.04616440147227996

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test2,y_pred2)
# Out:
# 7420.140335083181

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test2,y_pred2)
# Out:
# 134208530.40281543

# %%
mse = mean_squared_error(y_test2, y_pred2)
rmse = np.sqrt(mse)
rmse
# Out:
# 11584.840542830765

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test2, y_pred2)
print(mape)
mape = mape * 100
mape
# Out:
# 1.078185236681318
# 107.8185236681318

# %% [markdown]
# 70-30

# %%
model = SVR(kernel='rbf')
model.fit(X_train3, y_train3)
# Out:
# SVR()

# %%
y_pred3 = model.predict(X_test3)
print(y_pred3)
# Out:
# [9589.58840264 9647.46142648 9639.64648208 9566.32524629 9575.16488068
#  9500.97328089 9494.39054534 9636.14431436 9642.64169647 9622.49906896
#  9654.56113939 9553.25692679 9629.47398298 9589.00788616 9486.45206902
#  9664.32498698 9530.65585316 9525.81549064 9648.29598078 9668.08415631
#  9527.55933864 9659.59713888 9595.17225303 9581.94788412 9516.28689854
#  9584.31004332 9579.80289468 9655.83812992 9535.45957291 9518.36267737
#  9614.07305481 9522.53730766 9510.89205379 9617.72364011 9484.8228138
#  9490.90220163 9522.1977922  9658.26917156 9549.11871529 9570.62499741
#  9625.79751425 9488.78243015 9614.95503254 9611.66829562 9659.96682823
#  9657.25297076 9622.67830939 9543.89098522 9613.48566785 9643.05900127
#  9661.75518395 9638.60533326 9638.68199648 9540.33351038 9605.72538111
#  9498.06772748 9495.10154043 9651.79323601 9535.63198461 9670.96110361
#  9631.77111742 9643.73246969 9490.82583176 9510.87084081 9508.22117876
# ...

# %%
df = pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3})
print(df)
# Out:
#         Predicted       Actual
# 629   9589.588403  42983.45850
# 1087  9647.461426  11353.22760
# 283   9639.646482  11879.10405
# 790   9566.325246   5662.22500
# 594   9575.164881   5709.16440
# ...           ...          ...
# 924   9578.143148   6250.43500
# 873   9580.903591   6849.02600
# 731   9624.827993  10065.41300
# 363   9489.945970   2597.77900
# 10    9500.743050   2721.32080
#
# [402 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3,y_pred3)
# Out:
# -0.05639596021957494

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test3,y_pred3)
# Out:
# 7753.014808936214

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test3,y_pred3)
# Out:
# 144699914.72981322

# %%
mse = mean_squared_error(y_test3, y_pred3)
rmse = np.sqrt(mse)
rmse
# Out:
# 12029.127762635711

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test3, y_pred3)
print(mape)
mape = mape * 100
mape
# Out:
# 1.0656060226684811
# 106.56060226684812

# %% [markdown]
# 60-40

# %%
model = SVR(kernel='rbf')
model.fit(X_train4, y_train4)
# Out:
# SVR()

# %%
y_pred4 = model.predict(X_test4)
print(y_pred4)
# Out:
# [9652.06492744 9701.63779566 9694.93758725 9632.14375703 9639.71994904
#  9576.6770216  9570.61012538 9691.98886673 9697.57332323 9680.33341172
#  9707.78982293 9621.34171559 9686.23963164 9651.7297536  9563.85426737
#  9716.13980397 9602.03893563 9597.59238368 9702.37692549 9719.40781249
#  9599.21549069 9712.21052165 9656.94879548 9645.581049   9589.50501466
#  9647.56027733 9643.83395467 9708.8618669  9606.03891188 9591.47735036
#  9673.04216048 9595.02177896 9585.06609474 9676.2459615  9562.56416383
#  9567.65430134 9594.48867551 9710.9702965  9617.38413085 9635.95791708
#  9683.1795571  9566.25292308 9673.85019388 9670.99891168 9712.51451439
#  9710.05920301 9680.39170233 9613.39812275 9672.73523898 9697.92023913
#  9713.93511858 9694.05353599 9694.11459706 9609.84664998 9665.94122401
#  9574.18498226 9571.50308046 9705.36002166 9606.16147242 9721.88248623
#  9688.17832216 9698.50558301 9567.72990273 9585.1140318  9582.65948705
# ...

# %%
df = pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4})
print(df)
# Out:
#         Predicted       Actual
# 629   9652.064927  42983.45850
# 1087  9701.637796  11353.22760
# 283   9694.937587  11879.10405
# 790   9632.143757   5662.22500
# 594   9639.719949   5709.16440
# ...           ...          ...
# 479   9572.621540   1824.28540
# 538   9657.081008   8233.09750
# 117   9588.554106  19107.77960
# 5     9594.942465   3756.62160
# 1250  9574.370511  18648.42170
#
# [535 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4,y_pred4)
# Out:
# -0.05484658102191409

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test4,y_pred4)
# Out:
# 7754.855959916535

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test4,y_pred4)
# Out:
# 140902168.81528673

# %%
mse = mean_squared_error(y_test4, y_pred4)
rmse = np.sqrt(mse)
rmse
# Out:
# 11870.221936227086

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test4, y_pred4)
print(mape)
mape = mape * 100
mape
# Out:
# 1.0855005789680188
# 108.55005789680187

# %% [markdown]
# **DECISION TREE**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# 80-20

# %%
clf = DecisionTreeRegressor()
clf1 = clf.fit(X_train1,y_train1)
print(clf1)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1 = clf.predict(X_test1)
print(y_pred1)
# Out:
# [43896.3763  11842.62375 10807.4863   5649.715    5699.8375   3176.8159
#   1532.4697  25517.11363 12222.8983  24667.419   13012.20865 11884.04858
#   9863.4718   9225.2564   1137.011   13457.9608   4500.33925 37607.5277
#  20462.99766 15612.19335  4137.5227  13470.86    17929.30337  7726.854
#   4922.9159  48885.13561  8410.04685 48517.56315  4894.7533   2483.736
#   9549.5651   3756.6216   5138.2567  30284.64294  1621.8827   2438.0552
#  36197.699   13451.122    5124.1887  14478.33015 24667.419    2103.08
#  10702.6424  39556.4945  13470.86    12730.9996  10848.1343   5266.3656
#   9566.9909  11345.519   13143.33665 12105.32     9850.432   24915.04626
#  21232.18226  2395.17155  2850.68375 11743.9341   5926.846   14313.8463
#   9724.53    24227.33724 16586.49771  4435.0942   3956.07145  5138.2567
#   1748.774   41661.602   10197.7722  28923.13692 38415.474    4005.4225
#   1744.465    2103.08     8978.1851   1708.92575  5375.038    2523.1695
# ...

# %%
print("R-squared:", metrics.r2_score(y_test1, y_pred1))
# Out:
# R-squared: 0.6509988773347306

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test1, y_pred1))
# Out:
# Mean Squared Error: 45146723.52597167

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test1, y_pred1))
# Out:
# Mean Absolute Error: 3129.971602910448

# %% [markdown]
# 75-25

# %%
clf = DecisionTreeRegressor()
clf2 = clf.fit(X_train2,y_train2)
print(clf2)
# Out:
# DecisionTreeRegressor()

# %%
y_pred2 = clf.predict(X_test2)
print(y_pred2)
# Out:
# [48885.13561 11743.9341  10807.4863   5438.7491   6474.013   25081.76784
#   1917.3184  12094.478   12029.2867  24667.419   13451.122    6313.759
#  11305.93455  8534.6718   1137.011   13555.0049   4500.33925 37607.5277
#  20462.99766 27941.28758  3972.9247  13470.86    28340.18885  6849.026
#   4433.3877  43896.3763   8252.2843  47496.49445  5003.853    3756.6216
#   8347.1643   3736.4647   4058.1161  10848.1343   1131.5066   1725.5523
#  36950.2567  13451.122    5124.1887  15828.82173 24667.419    2103.08
#  10702.6424  40720.55105 12979.358   12730.9996  10848.1343   4992.3764
#   9174.13565 11345.519   13555.0049  12096.6512  10796.35025  4753.6368
#  25656.57526  1972.95     2154.361   12430.95335  5003.853   14410.9321
#  11394.06555 11090.7178   1256.299    3847.674    3956.07145  4058.1161
#   1984.4533  41661.602   10797.3362  28923.13692 38415.474    4005.4225
#   1744.465    2103.08     8978.1851   1708.92575  4753.6368   4137.5227
# ...

# %%
print("R-squared:", metrics.r2_score(y_test2, y_pred2))
# Out:
# R-squared: 0.6403413138452456

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test2, y_pred2))
# Out:
# Mean Squared Error: 46139271.846286386

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test2, y_pred2))
# Out:
# Mean Absolute Error: 3154.165776208955

# %% [markdown]
# 70-30

# %%
clf = DecisionTreeRegressor()
clf3 = clf.fit(X_train3,y_train3)
print(clf3)
# Out:
# DecisionTreeRegressor()

# %%
y_pred3 = clf.predict(X_test3)
print(y_pred3)
# Out:
# [48885.13561 11743.9341  10807.4863   5438.7491   5979.731    3213.62205
#   1532.4697  11881.9696  12029.2867  24667.419   13451.122    6985.50695
#   9487.6442   9411.005    1137.011   13429.0354   4500.33925 55135.40209
#  14235.072   15612.19335  4137.5227  13470.86     7731.85785  8522.003
#   4433.3877  43896.3763  14478.33015 47496.49445  4894.7533   2866.091
#   9549.5651   3756.6216  20177.67113 30284.64294  1629.8335   2438.0552
#  36950.2567  13451.122   24915.04626 15828.82173 24667.419    1980.07
#  10381.4787  40720.55105 13470.86    12730.9996  10848.1343   4883.866
#   9361.3268  11534.87265 13457.9608  11881.9696  24476.47851  5989.52365
#  21232.18226  2395.17155  2850.68375 12430.95335 27375.90478 14410.9321
#  11394.06555 11090.7178  16586.49771  5257.50795  3392.9768  20177.67113
#   1744.465   42124.5153  10797.3362  28923.13692 38415.474    4005.4225
#   1744.465    1837.237    8978.1851   1708.92575  6334.34355  2866.091
# ...

# %%
print("R-squared:", metrics.r2_score(y_test3, y_pred3))
# Out:
# R-squared: 0.6434397566233926

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test3, y_pred3))
# Out:
# Mean Squared Error: 48839865.69005105

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test3, y_pred3))
# Out:
# Mean Absolute Error: 3421.253911666667

# %% [markdown]
# 60-40

# %%
clf = DecisionTreeRegressor()
clf4 = clf.fit(X_train4,y_train4)
print(clf4)
# Out:
# DecisionTreeRegressor()

# %%
y_pred4 = clf.predict(X_test4)
print(y_pred4)
# Out:
# [44202.6536  11454.0215  10713.644    5397.6167   5966.8874   3213.62205
#   1532.4697  11881.9696  11454.0215  24106.91255 13451.122    6985.50695
#  10072.05505  8515.7587   1137.011   13844.7972   3866.8552  44585.45587
#  14235.072   14119.62     3972.9247  13470.86    28340.18885  8522.003
#   4433.3877  41949.2441  19144.57652 46255.1125   5002.7827   3866.8552
#  10848.1343   4137.5227  23288.9284  30284.64294  2205.9808   1725.5523
#  36950.2567  13451.122    4536.259   15828.82173 35069.37452  2103.08
#  11085.5868  40974.1649  13470.86    13217.0945  10977.2063   5227.98875
#   9182.17    11345.519   11743.299   11881.9696  10713.644   11326.71487
#  21232.18226  2103.08    10795.93733 12235.8392   4889.9995  14313.8463
#   9724.53    10338.9316   1980.07     5312.16985 18903.49141 23288.9284
#   1744.465   42760.5022  10797.3362  28923.13692 40941.2854   3279.86855
#   1744.465    1837.237   10600.5483   2045.68525 18963.17192  2497.0383
# ...

# %%
print("R-squared:", metrics.r2_score(y_test4, y_pred4))
# Out:
# R-squared: 0.6260986350834876

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test4, y_pred4))
# Out:
# Mean Squared Error: 49944242.307439476

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test4, y_pred4))
# Out:
# Mean Absolute Error: 3478.2936305420562

# %% [markdown]
# **RANDOM FOREST**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import plot_tree

from matplotlib import pyplot as plt

# %% [markdown]
# 80-20

# %%
print(X_train1.shape)
print(y_train1.shape)
print(X_test1.shape)
print(y_test1.shape)
# Out:
# (1069, 8)
# (1069,)
# (268, 8)
# (268,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train1, y_train1)
# Out:
# RandomForestRegressor()

# %%
y_pred1 = rf.predict(X_test1)
print(y_pred1)
# Out:
# [47412.9624774  11895.0749052  11774.5885793   9561.3779623
#   6233.3399507   6458.7245661   1896.7848042  15013.8524102
#  12009.6019309  24087.160012   14314.2132253   8249.618444
#  12672.3298003   9895.7874311   1177.966586   13780.9347867
#   5456.8042261  41856.2512316  14722.7479049  21554.2661736
#   4718.2618228  15987.4941671  12603.9317702   9730.6324416
#   6850.9523383  43922.4397214   9586.8425774  47953.6894828
#   5252.3040759   3869.6816526  10141.1172444   3837.406981
#   7304.3758168  21471.2167085   3452.59141569  2040.9298365
#  39481.467773   14543.3845228   9786.794148   11036.7791903
#  24702.8574936   2250.8684016  11514.0535559  41002.034604
#  14667.4501081  12733.599859   11634.7506038   5366.1511274
#  10321.6933132  11511.414145   13489.1440324  12617.7333871
#  13416.1884963  11702.2248576  14027.0799658   4893.6081264
#   5804.2030271  12115.172617    6951.0081485  14222.1003703
#  10774.6740245  16095.5954727   4335.4689965   8920.2165398
# ...

# %%
print("R-squared:", metrics.r2_score(y_test1, y_pred1))
# Out:
# R-squared: 0.824493792362458

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test1, y_pred1))
# Out:
# Mean Squared Error: 22703451.99119439

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test1, y_pred1))
# Out:
# Mean Absolute Error: 2649.448446138582

# %% [markdown]
# 75-25

# %%
print(X_train2.shape)
print(y_train2.shape)
print(X_test2.shape)
print(y_test2.shape)
# Out:
# (1002, 8)
# (1002,)
# (335, 8)
# (335,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train2, y_train2)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = rf.predict(X_test2)
print(y_pred2)
# Out:
# [46560.1263524  11946.8807686  13602.0131177   9089.6501837
#   6098.6254768   7028.1702617   2067.4327623  15699.8898247
#  11993.8807652  24011.2778835  15463.8966254   9264.4390397
#  12529.0691546   9866.4543119   1153.101097   13683.5064901
#   5709.9266458  41067.5524134  16495.5428646  21508.9061092
#   4389.2559631  15839.3231175  11632.0888818   8901.4840282
#   8103.2663361  43853.8942096   9475.6715216  47501.1695069
#   4987.6367545   3592.049293   10790.4264922   3825.588447
#   8477.0093227  20948.5601023   5530.77233449  2044.1003688
#  39839.8756114  15750.6790155  11619.1513184  11662.6519552
#  24635.7842137   2140.8020038  11673.2136268  41046.752552
#  14782.3715482  12910.9686267  12446.7355406   5578.049266
#  10671.5882373  11496.0855592  15463.3098183  13711.7325055
#  13418.0453726  11055.6268322  14893.1879117   4599.4571123
#   4102.8080373  12146.896532    8399.4641203  14443.4179921
#  11706.2790241  15561.4623695   6179.9197235   9111.3697324
# ...

# %%
print("R-squared:", metrics.r2_score(y_test2, y_pred2))
# Out:
# R-squared: 0.8153879786190775

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test2, y_pred2))
# Out:
# Mean Squared Error: 23683187.89031482

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test2, y_pred2))
# Out:
# Mean Absolute Error: 2759.360339154596

# %% [markdown]
# 70-30

# %%
print(X_train3.shape)
print(y_train3.shape)
print(X_test3.shape)
print(y_test3.shape)
# Out:
# (935, 8)
# (935,)
# (402, 8)
# (402,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train3, y_train3)
# Out:
# RandomForestRegressor()

# %%
y_pred3 = rf.predict(X_test3)
print(y_pred3)
# Out:
# [47113.4759037  12488.7519457  13152.1151635   8097.0532936
#   6615.3429359   8579.066165    2373.3920785  14822.8852373
#  12127.5577081  24047.061639   14739.1514404   8700.165061
#  13481.1523181  10349.9807326   1170.12582    13888.5134073
#   5986.5279626  39584.2057875  15944.680248   19870.2234158
#   4391.07229379 17221.8498829  10700.1593281   9622.9843783
#   8729.538266   43136.4967894  10060.9983825  47154.0164739
#   5247.5210148   3615.6524055  10245.9604709   4011.8425491
#   8682.9061386  19837.9274375   3310.04985279  2462.3355154
#  37973.4921262  14442.5517801  11344.0816071  11457.3418537
#  24144.020064    2097.3907843  11883.5229903  40784.8455045
#  16088.4767412  12834.3622156  12055.718967    5188.7887004
#  11197.5919668  11416.2272759  14844.6138234  13747.3443756
#  15235.9018022  10156.7604664  13498.0289038   6477.2444107
#   3890.0291036  12149.3889905   9022.0973426  14276.1387528
#  11275.2178752  16394.9767995   5737.2717817   9157.4334107
# ...

# %%
print("R-squared:", metrics.r2_score(y_test3, y_pred3))
# Out:
# R-squared: 0.8299034770398582

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test3, y_pred3))
# Out:
# Mean Squared Error: 23298983.804381803

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test3, y_pred3))
# Out:
# Mean Absolute Error: 2768.3987983205466

# %% [markdown]
# 60-40

# %%
print(X_train4.shape)
print(y_train4.shape)
print(X_test4.shape)
print(y_test4.shape)
# Out:
# (802, 8)
# (802,)
# (535, 8)
# (535,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train4, y_train4)
# Out:
# RandomForestRegressor()

# %%
y_pred4 = rf.predict(X_test4)
print(y_pred4)
# Out:
# [46740.264252   12642.9013551  12425.4272655   9260.8211994
#   6694.5830197   7515.3203537   2586.870726   14450.372164
#  11774.9759665  24196.0849682  16725.2703025  10220.2738315
#  13259.7903911  11009.6847598   1154.246391   14126.8256934
#   7374.3419337  39986.3070516  15593.0132142  20104.0564465
#   4925.64112529 17588.3489196  11258.5018477  10162.8073733
#   8736.8831729  43097.8610936  10174.4626747  47307.8186163
#   6047.336231    3610.564996   10385.088606    4790.3150221
#   6907.7739826  20825.6754788   3863.9374086   2284.8885954
#  37964.2897891  15864.8601404   6967.1093309  10628.7064624
#  25184.8739894   2173.3682679  10932.1911656  41053.6256588
#  16624.1526327  13195.3814409  13097.1221322   5742.0503905
#  10071.969339   11331.623227   15364.9043918  13055.2261814
#  14299.3056728   8737.5131336  14219.4051811   5867.6089309
#   4294.4173764  12169.295955    8029.021763   14528.8523081
#  11415.7179155  16783.6627015   7041.9712814   7180.7818388
# ...

# %%
print("R-squared:", metrics.r2_score(y_test4, y_pred4))
# Out:
# R-squared: 0.8199886924799519

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test4, y_pred4))
# Out:
# Mean Squared Error: 24045187.325988397

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test4, y_pred4))
# Out:
# Mean Absolute Error: 2733.2539956137016

# %% [markdown]
# **XGBOOST**

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %% [markdown]
# 80-20

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train1, y_train1)

# %%
y_pred1 = model.predict(X_test1)
print(y_pred1)
# Out:
# [53555.18    11461.423   12328.625   11621.41     4761.934    7750.494
#   1529.4352  20414.572   11197.441   25815.15    14904.92     8241.342
#  10975.551   12085.234     783.871   21445.992    5929.791   47263.504
#  14852.5     25863.543    4428.945   17889.02     9720.698    7515.8193
#  11295.879   46785.555    9298.674   49988.33     3783.8862   1293.941
#   8658.964    2485.7837   3508.8274  12714.674    2851.102    1347.1912
#  38437.418   14930.253    9465.392    9512.608   24132.133    1301.1206
#  11352.383   38335.387   13748.171   12944.448    6926.9644   4855.4585
#   9496.143   10398.47    14612.465   13194.611   13377.695   16014.891
#  13593.789    3873.0288   2928.6475  10825.764    4624.3604  19449.688
#  10009.841   19169.473    6009.4956   9024.99     7403.1436   4948.1504
#   3398.7964  47039.38    10589.582   14695.782   41257.08     2367.199
#   2129.8516   1666.5055  10186.071    -668.3416   7280.8687   1737.5793
# ...

# %%
mse = mean_squared_error(y_test1, y_pred1)
r2 = r2_score(y_test1, y_pred1)
mae = mean_absolute_error(y_test1, y_pred1)


print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 26612354.110278934
# R-squared: 0.7942765114303354
# Mean Absolute Error: 3030.090976026156

# %% [markdown]
# 75-25

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train2, y_train2)

# %%
y_pred2 = model.predict(X_test2)
print(y_pred2)
# Out:
# [47234.363   12293.657   14358.452   15422.894    5203.304    6746.9146
#   2916.7273  15838.477    9629.92    23697.68    14309.788    6042.868
#  10656.107   10015.885     206.15898 20115.781    4624.1807  38750.785
#  18051.96    28865.8      6930.7383  16832.293    9616.425    9373.786
#  12299.351   49615.45    10394.002   50122.004    3656.022    2653.9148
#   9381.347    2266.0955   4609.477   12962.549    2205.9822   1771.667
#  37316.47    14918.681    6010.046   11280.594   22056.865    1799.9093
#  10585.022   37460.227   12244.5625  13379.78     9379.888    4679.5107
#   8571.103   10079.0625  21198.996   14879.945   15378.155   11355.631
#  12012.355    2470.224    2166.549   11033.773    9028.857   19008.867
#   9367.639   18910.092    4734.189    8398.068    9136.514    5547.4834
#   1031.5118  46467.7     11039.85    15906.747   43892.105    3067.5862
#   1435.9004    932.61475 10748.679     784.6401   6763.8604   4346.672
# ...

# %%
mse = mean_squared_error(y_test2, y_pred2)
r2 = r2_score(y_test2, y_pred2)
mae = mean_absolute_error(y_test2, y_pred2)
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 26452349.315623194
# R-squared: 0.7938021815285887
# Mean Absolute Error: 3010.910351285215

# %% [markdown]
# 70-30

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train3, y_train3)

# %%
y_pred3 = model.predict(X_test3)
print(y_pred3)
# Out:
# [ 4.81782578e+04  1.24516182e+04  1.26979551e+04  1.61493252e+04
#   5.69885156e+03  8.58898828e+03  3.71203149e+03  1.96180547e+04
#   1.11422031e+04  2.41260840e+04  1.71203340e+04  7.81330127e+03
#   1.06140430e+04  1.08805254e+04  3.07392731e+02  1.83872949e+04
#   8.39939551e+03  3.99971211e+04  1.26079463e+04  2.11640801e+04
#   4.95462988e+03  1.62659121e+04  1.01049775e+04  1.14702324e+04
#   1.00714258e+04  4.41945312e+04  1.43219414e+04  4.61325742e+04
#   5.11410449e+03  1.98707837e+03  8.80420996e+03  1.56778589e+03
#   6.00668604e+03  1.52410918e+04  3.96391870e+03  8.71464783e+02
#   3.69745664e+04  1.66016973e+04  6.07477295e+03  1.06708662e+04
#   2.38437207e+04  1.29949487e+03  1.23863184e+04  3.86966953e+04
#   1.25583916e+04  1.28351748e+04  1.00489668e+04  4.61089453e+03
#   8.96797363e+03  1.07243584e+04  1.99849082e+04  1.15791650e+04
#   1.18760703e+04  1.43928350e+04  1.33841709e+04  7.33394385e+03
# ...

# %%
mse = mean_squared_error(y_test3, y_pred3)
r2 = r2_score(y_test3, y_pred3)
mae = mean_absolute_error(y_test3, y_pred3)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 25281575.935384512
# R-squared: 0.8154293681790127
# Mean Absolute Error: 2995.790348398732

# %% [markdown]
# 60-40

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train4, y_train4)

# %%
y_pred4 = model.predict(X_test4)
print(y_pred4)
# Out:
# [ 4.75067109e+04  1.18896758e+04  1.07371895e+04  1.44543398e+04
#   5.29664795e+03  5.15140576e+03  3.16699561e+03  1.57472090e+04
#   1.12421279e+04  2.36575508e+04  1.80471992e+04  6.69847217e+03
#   1.12745293e+04  1.16726602e+04  7.76652283e+02  2.13243242e+04
#   1.29334805e+04  3.85150742e+04  1.13182998e+04  2.30158789e+04
#   7.72779736e+03  1.58137031e+04  1.06591201e+04  9.11109863e+03
#   6.14938379e+03  4.52362070e+04  1.07606777e+04  4.69342695e+04
#   5.39566113e+03  2.05246362e+03  1.08199766e+04  2.47226978e+03
#   4.80368701e+03  1.63744688e+04  1.82026709e+03  1.42422937e+03
#   3.69769023e+04  1.58223682e+04  1.03254014e+04  1.25248184e+04
#   2.42987656e+04  1.85375708e+03  1.05101748e+04  4.05817969e+04
#   1.21194355e+04  1.35672598e+04  1.10144814e+04  4.93424707e+03
#   6.64232275e+03  1.03818447e+04  1.68328535e+04  1.16538740e+04
#   1.43368037e+04  1.63478213e+04  1.52507207e+04  5.64636377e+03
# ...

# %%
mse = mean_squared_error(y_test4, y_pred4)
r2 = r2_score(y_test4, y_pred4)
mae = mean_absolute_error(y_test4, y_pred4)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 28709646.039526097
# R-squared: 0.7850688018376489
# Mean Absolute Error: 3034.979724061398

# %% [markdown]
# **ADABOOST**

# %%
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# 80-20

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train1, y_train1)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred1 = model.predict(X_test1)
print(y_pred1)
# Out:
# [46699.55313864 14724.09342165 15686.0603305   6992.14362925
#   6992.14362925  5404.47224727  5404.47224727 17458.23664369
#  14724.09342165 26299.07696318 14724.09342165  9117.35326937
#  14724.09342165 12860.44120335  5404.47224727 14724.09342165
#   6992.14362925 39836.89793294 17458.23664369 17458.23664369
#   6992.14362925 14724.09342165  8736.76553005  9117.35326937
#   9117.35326937 46699.55313864  9117.35326937 46699.55313864
#   8736.76553005  6992.14362925 14837.74299438  6992.14362925
#   9117.35326937 17458.23664369  5404.47224727  8736.76553005
#  38211.07887932 14724.09342165  9117.35326937  9117.35326937
#  26299.07696318  8736.76553005 17458.23664369 46699.55313864
#  14724.09342165 14724.09342165 17458.23664369  6992.14362925
#  12979.13916821 14724.09342165 14724.09342165 17458.23664369
#  14724.09342165  9117.35326937 11293.36929838  5404.47224727
#   5404.47224727 14724.09342165  9117.35326937 14724.09342165
# ...

# %%
r2 = r2_score(y_test1, y_pred1)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test1, y_pred1)
print(f"Mean Squared Error: {mse:.2f}")

mae=mean_absolute_error(y_test1, y_pred1)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.82
# Mean Squared Error: 23615256.63
# Mean Absolute Error: 3928.00

# %% [markdown]
# 75-25

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train2, y_train2)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred2 = model.predict(X_test2)
print(y_pred2)
# Out:
# [45539.11796547 13546.52392333 17361.34404137 10493.64585179
#   9610.26718225  6477.41861918  6477.41861918 18049.74178881
#  13546.52392333 26197.46834111 13546.52392333 10493.64585179
#  13546.52392333 10493.64585179  6477.41861918 13546.52392333
#   6477.41861918 41659.68894621 18049.74178881 18049.74178881
#   6477.41861918 13546.52392333 10493.64585179 10493.64585179
#   8236.08549713 45539.11796547 10493.64585179 43925.77171767
#  10493.64585179  6477.41861918 13232.8043879   6477.41861918
#   8236.08549713 15691.52592951  6477.41861918  6923.92024424
#  38094.76969396 13546.52392333 10493.64585179 10493.64585179
#  26197.46834111  6449.47628177 13232.8043879  43925.77171767
#  13546.52392333 13546.52392333 15691.52592951  6477.41861918
#  13217.94156627 13546.52392333 13546.52392333 18049.74178881
#  13546.52392333  8236.08549713 13217.94156627  6449.47628177
#   6477.41861918 13546.52392333 10493.64585179 13546.52392333
# ...

# %%
r2 = r2_score(y_test2, y_pred2)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test2, y_pred2)
print(f"Mean Squared Error: {mse:.2f}")

mae=mean_absolute_error(y_test2, y_pred2)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.81
# Mean Squared Error: 24295122.60
# Mean Absolute Error: 3954.25

# %% [markdown]
# 70-30

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train3, y_train3)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred3 = model.predict(X_test3)
print(y_pred3)
# Out:
# [45093.21461432 13875.18307635 17861.12879047 10042.39669494
#  10042.39669494  5645.12177204  5645.12177204 17861.12879047
#  13875.18307635 26252.40670405 13875.18307635  6557.26836235
#  13875.18307635 11437.05388203  5645.12177204 13875.18307635
#   5645.12177204 38080.80571135 17861.12879047 17861.12879047
#   5645.12177204 13875.18307635 11437.05388203 10252.31722606
#  10252.31722606 45093.21461432 10252.31722606 45759.23895125
#  10341.67172185  5645.12177204 12372.80724793  5645.12177204
#  10341.67172185 12372.80724793  5645.12177204 10252.31722606
#  38080.80571135 13875.18307635 10341.67172185 10252.31722606
#  26252.40670405  4961.99899432 12372.80724793 45093.21461432
#  13875.18307635 13875.18307635 12372.80724793  4961.99899432
#  10042.39669494 13875.18307635 13875.18307635 17861.12879047
#  13875.18307635 10341.67172185 12372.80724793  5645.12177204
#   5645.12177204 13875.18307635 10252.31722606 13875.18307635
# ...

# %%
r2 = r2_score(y_test3, y_pred3)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test3, y_pred3)
print(f"Mean Squared Error: {mse:.2f}")

mae=mean_absolute_error(y_test3, y_pred3)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.81
# Mean Squared Error: 25854001.13
# Mean Absolute Error: 3987.05

# %% [markdown]
# 60-40

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train4, y_train4)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred4 = model.predict(X_test4)
print(y_pred4)
# Out:
# [42599.54446609 15908.69720271 14929.32885373  7403.61409204
#   7403.61409204  5579.31326377  5579.31326377 14929.32885373
#  15908.69720271 25666.16788932 14929.32885373 10096.58703939
#  15908.69720271 10096.58703939  5579.31326377 15908.69720271
#   7403.61409204 40464.80740031 14929.32885373 15908.69720271
#   7403.61409204 14929.32885373  7403.61409204 10096.58703939
#   9712.70380155 42599.54446609 10096.58703939 45119.40293581
#  10096.58703939  7403.61409204 14929.32885373  7403.61409204
#  10096.58703939 17200.13533995  5579.31326377  7423.35024226
#  40464.80740031 14929.32885373 10096.58703939 10096.58703939
#  25666.16788932  7423.35024226 14929.32885373 42599.54446609
#  14929.32885373 14929.32885373 15908.69720271  7403.61409204
#  15908.69720271 14549.71862944 14929.32885373 14929.32885373
#  14549.71862944 10096.58703939 12950.95343669  5579.31326377
#   5579.31326377 15908.69720271 10096.58703939 14929.32885373
# ...

# %%
r2 = r2_score(y_test4, y_pred4)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test4, y_pred4)
print(f"Mean Squared Error: {mse:.2f}")

mae=mean_absolute_error(y_test4, y_pred4)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.80
# Mean Squared Error: 26801868.46
# Mean Absolute Error: 4148.44

# %% [markdown]
# ANN before VIF

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
X_train1 ,X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.20, random_state=42)
X_train2 ,X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.25, random_state=42)
X_train3 ,X_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.30, random_state=42)
X_train4 ,X_test4, y_train4, y_test4 = train_test_split(X, y, test_size=0.40, random_state=42)

# %% [markdown]
# 80-20

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model1= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),

                            tf.keras.layers.Dense(8),




                            tf.keras.layers.Dense(6),

                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model1.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model1.fit(X_train1, y_train1, epochs= 300, verbose=1)
# Out:
# Epoch 1/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13201.3740 - mae: 13201.3740
# Epoch 2/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13075.6133 - mae: 13075.6133
# Epoch 3/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12782.3174 - mae: 12782.3174
# Epoch 4/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 11989.0371 - mae: 11989.0371
# Epoch 5/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10046.4814 - mae: 10046.4814
# Epoch 6/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7651.4624 - mae: 7651.4624
# Epoch 7/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7317.4683 - mae: 7317.4683
# Epoch 8/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7288.5996 - mae: 7288.5996
# Epoch 9/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7246.8604 - mae: 7246.8604
# Epoch 10/300
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7212.5034 - mae: 7212.5034
# Epoch 11/300
# ...

# %%
model1.evaluate(X_test1, y_test1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3483.9856 - mae: 3483.9856
# [3336.997802734375, 3336.997802734375]

# %%
model1.summary();
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 75-25

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model2= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),
                            tf.keras.layers.Dense(8),



                            tf.keras.layers.Dense(6),
                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),
                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model2.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model2.fit(X_train2, y_train2, epochs= 300, verbose=1)
# Out:
# Epoch 1/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - loss: 13466.0850 - mae: 13466.0850
# Epoch 2/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13459.5898 - mae: 13459.5898
# Epoch 3/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13443.1143 - mae: 13443.1143
# Epoch 4/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13376.4854 - mae: 13376.4854
# Epoch 5/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13110.9990 - mae: 13110.9990
# Epoch 6/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12182.3086 - mae: 12182.3086
# Epoch 7/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9781.2891 - mae: 9781.2891
# Epoch 8/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7543.2417 - mae: 7543.2417
# Epoch 9/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7434.3350 - mae: 7434.3350
# Epoch 10/300
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7418.4463 - mae: 7418.4463
# Epoch 11/300
# ...

# %%
model2.evaluate(X_test2, y_test2)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3516.6248 - mae: 3516.6248
# [3358.0234375, 3358.0234375]

# %%
model2.summary();
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 70-30

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model3= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),

                            tf.keras.layers.Dense(8),



                            tf.keras.layers.Dense(6),

                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model3.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model3.fit(X_train3, y_train3, epochs= 300, verbose=1)
# Out:
# Epoch 1/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 13042.7891 - mae: 13042.7891
# Epoch 2/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12942.0381 - mae: 12942.0381
# Epoch 3/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12726.5869 - mae: 12726.5869
# Epoch 4/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12211.4365 - mae: 12211.4365
# Epoch 5/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10989.6689 - mae: 10989.6689
# Epoch 6/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8865.0498 - mae: 8865.0498
# Epoch 7/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7501.3086 - mae: 7501.3086
# Epoch 8/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7448.6104 - mae: 7448.6104
# Epoch 9/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7427.4512 - mae: 7427.4512
# Epoch 10/300
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7399.2847 - mae: 7399.2847
# Epoch 11/300
# ...

# %%
model3.evaluate(X_test3, y_test3)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3596.7861 - mae: 3596.7861
# [3548.8759765625, 3548.8759765625]

# %%
model3.summary();
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_15 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 60-40

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model4= tf.keras.Sequential([

                            tf.keras.layers.Dense(16),

                            tf.keras.layers.Dense(8),



                            tf.keras.layers.Dense(6),

                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),

                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model4.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate = 0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model4.fit(X_train4, y_train4, epochs= 300, verbose=1)
# Out:
# Epoch 1/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 13455.8965 - mae: 13455.8965
# Epoch 2/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13402.8203 - mae: 13402.8203
# Epoch 3/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 13283.6426 - mae: 13283.6426
# Epoch 4/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12999.2432 - mae: 12999.2432
# Epoch 5/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12328.5986 - mae: 12328.5986
# Epoch 6/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 10861.2324 - mae: 10861.2324
# Epoch 7/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8702.1426 - mae: 8702.1426
# Epoch 8/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7539.9355 - mae: 7539.9355
# Epoch 9/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7459.7407 - mae: 7459.7407
# Epoch 10/300
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 7450.2437 - mae: 7450.2437
# Epoch 11/300
# ...

# %%
model4.evaluate(X_test4, y_test4)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4131.7539 - mae: 4131.7539
# [4067.277099609375, 4067.277099609375]

# %%
model4.summary();
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# **Multi collinearity**

# %%
import pandas as pd
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.model_selection import train_test_split
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
print(X.shape)
print(X.info())
# Out:
# (1337, 8)
# <class 'pandas.core.frame.DataFrame'>
# Index: 1337 entries, 0 to 1337
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               1337 non-null   int64
#  1   bmi               1337 non-null   float64
#  2   children          1337 non-null   int64
#  3   sex_male          1337 non-null   int64
#  4   smoker_yes        1337 non-null   int64
#  5   region_northwest  1337 non-null   int64
#  6   region_southeast  1337 non-null   int64
#  7   region_southwest  1337 non-null   int64
# dtypes: float64(1), int64(7)
# memory usage: 94.0 KB
# None

# %%
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
  # Select only numeric features
    X_numeric = X.select_dtypes(include=np.number)

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X_numeric.columns
    vif["VIF"] = [variance_inflation_factor(X_numeric.values, i).round(1)
                  for i in range(X_numeric.shape[1])]

    return(vif)

# Assuming X is your original DataFrame
calc_vif(X)
# Out:
#           variables   VIF
# 0               age   7.7
# 1               bmi  11.4
# 2          children   1.8
# 3          sex_male   2.0
# 4        smoker_yes   1.3
# 5  region_northwest   1.9
# 6  region_southeast   2.3
# 7  region_southwest   2.0

# %%
calc_vif(X.drop('bmi', axis=1))
# Out:
#           variables  VIF
# 0               age  3.9
# 1          children  1.8
# 2          sex_male  1.9
# 3        smoker_yes  1.2
# 4  region_northwest  1.7
# 5  region_southeast  1.8
# 6  region_southwest  1.7

# %%
calc_vif(X.drop(['bmi','age'], axis=1))
# Out:
#           variables  VIF
# 0          children  1.6
# 1          sex_male  1.7
# 2        smoker_yes  1.2
# 3  region_northwest  1.3
# 4  region_southeast  1.4
# 5  region_southwest  1.3

# %%
from sklearn.model_selection import train_test_split
X_nomulti=X.drop(['bmi','age'], axis=1)
X_train1_nomulti, X_test1_nomulti, y_train1_nomulti, y_test1_nomulti = train_test_split(X_nomulti, y, test_size=0.20, train_size=0.80, random_state=1)
X_train2_nomulti, X_test2_nomulti, y_train2_nomulti, y_test2_nomulti = train_test_split(X_nomulti, y, test_size=0.25, train_size=0.75, random_state=1)
X_train3_nomulti, X_test3_nomulti, y_train3_nomulti, y_test3_nomulti = train_test_split(X_nomulti, y, test_size=0.30, train_size=0.70, random_state=1)
X_train4_nomulti, X_test4_nomulti, y_train4_nomulti, y_test4_nomulti = train_test_split(X_nomulti, y, test_size=0.40, train_size=0.60, random_state=1)

# %% [markdown]
# **linear regression after vif**

# %% [markdown]
# 80-20

# %%
lm2 = LinearRegression()
lm2.fit(X_train1_nomulti, y_train1_nomulti)
y_pred1 = lm2.predict(X_test1_nomulti)
print((metrics.r2_score(y_test1_nomulti, y_pred1)))
print((metrics.mean_squared_error(y_test1_nomulti, y_pred1)))
print((metrics.mean_absolute_error(y_test1_nomulti,y_pred1)))
# Out:
# 0.64710278441521
# 45650721.41722718
# 5184.084688174947

# %% [markdown]
# 75-25

# %%
lm2 = LinearRegression()
lm2.fit(X_train2_nomulti, y_train2_nomulti)
y_pred1 = lm2.predict(X_test2_nomulti)
print((metrics.r2_score(y_test2_nomulti, y_pred2)))
print((metrics.mean_squared_error(y_test2_nomulti, y_pred2)))
print((metrics.mean_absolute_error(y_test2_nomulti,y_pred2)))
# Out:
# 0.8106179069076932
# 24295122.604782254
# 3954.2548377759003

# %% [markdown]
# 70-30

# %%
lm2 = LinearRegression()
lm2.fit(X_train3_nomulti, y_train3_nomulti)
y_pred1 = lm2.predict(X_test3_nomulti)
print((metrics.r2_score(y_test3_nomulti, y_pred3)))
print((metrics.mean_squared_error(y_test3_nomulti, y_pred3)))
print((metrics.mean_absolute_error(y_test3_nomulti,y_pred3)))
# Out:
# 0.8112503217161303
# 25854001.13351317
# 3987.051918054025

# %% [markdown]
# 60-40

# %%
lm2 = LinearRegression()
lm2.fit(X_train4_nomulti, y_train4_nomulti)
y_pred1 = lm2.predict(X_test4_nomulti)
print((metrics.r2_score(y_test4_nomulti,y_pred4)))
print((metrics.mean_squared_error(y_test4_nomulti, y_pred4)))
print((metrics.mean_absolute_error(y_test4_nomulti,y_pred4)))
# Out:
# 0.7993511416933529
# 26801868.45591189
# 4148.4440522716195

# %% [markdown]
# **K Nearest Neighbors after VIF**

# %%
from sklearn.neighbors import KNeighborsRegressor

# %% [markdown]
# 80-20

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train1_nomulti,y_train1_nomulti)
# Out:
# KNeighborsRegressor()

# %%
y_pred1 = model.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [28699.301156  5026.81204  12171.364632  6760.39476   6362.5022
#  12837.869828  6362.5022    7944.67867   8377.56487  38974.463578
#   6760.39476  12679.300068  5026.81204   9796.42399   6362.5022
#   5026.81204   5026.81204  39181.994642 14809.580606 12679.300068
#   8377.56487   7175.46249   8377.56487   6228.387    13692.337012
#  36808.46166   7553.27084  38633.097036  5711.02925   4149.91598
#   5641.16012   6760.39476   5641.16012   9043.66312   6760.39476
#   6439.07322  28040.71284   6760.39476   5641.16012   7694.76869
#  27120.80404   8443.7444   12043.443812 28040.71284   8849.556074
#   4149.91598  10247.87366  12837.869828  8377.56487   8849.556074
#   6362.5022   14809.580606  8849.556074 10247.87366   7175.46249
#   8849.556074  8377.56487   8377.56487   6228.387     8849.556074
#   8443.7444    6760.39476   8849.556074  9336.59066  12171.364632
#   5641.16012   7175.46249  23431.3654   12837.869828  6362.5022
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1_nomulti})
print(df)
# Out:
#          Predicted       Actual
# 629   28699.301156  42983.45850
# 1087   5026.812040  11353.22760
# 283   12171.364632  11879.10405
# 790    6760.394760   5662.22500
# 594    6362.502200   5709.16440
# ...            ...          ...
# 1164   5711.029250   7153.55390
# 962   10330.414882  14474.67500
# 1158  12837.869828   2459.72010
# 1241  36808.461660  49577.66240
# 216    8377.564870  10355.64100
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1_nomulti,y_pred1)
# Out:
# 0.5858711856503664

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test1_nomulti,y_pred1)
# Out:
# 5464.84284991791

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1_nomulti,y_pred1)
# Out:
# 53571630.2079447

# %%
mse = mean_squared_error(y_test1_nomulti, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# 7319.264321497393

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test1_nomulti, y_pred1)
print(mape)
mape = mape * 100
mape
# Out:
# 0.9193543301438354
# 91.93543301438353

# %% [markdown]
# 75-25

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train2_nomulti,y_train2_nomulti)
# Out:
# KNeighborsRegressor()

# %%
y_pred2 = model.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [28034.856336  4830.53083  11295.519732  4385.29078   6362.5022
#  14690.005788  6362.5022    8980.27481   8879.96686  33727.34617
#   4385.29078  10785.227888  4830.53083  12705.250732  6362.5022
#   4830.53083   4830.53083  36403.820148 14752.327832 10785.227888
#   8879.96686   4410.802     8879.96686   6896.1104   18351.9262
#  39915.54756   8411.09994  34861.519516  9538.526578  7905.43964
#   5547.45418   4385.29078   5547.45418  12409.737606  4385.29078
#   6801.6336   34785.05424   4385.29078   5547.45418   8866.025156
#  21312.0361    9654.063    12223.547392 34785.05424   5757.8594
#   7905.43964   9854.00651  14690.005788  8879.96686   5757.8594
#   6362.5022   14752.327832  5757.8594    9854.00651   4410.802
#   5757.8594    8879.96686   8879.96686   6896.1104    5757.8594
#   9654.063     4385.29078   5757.8594    9149.19765  11295.519732
#   5547.45418   4410.802    23431.3654   14690.005788  6362.5022
#  15204.5958    8411.09994   4410.802     9654.063     6742.98288
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2_nomulti})
print(df)
# Out:
#          Predicted       Actual
# 629   28034.856336  42983.45850
# 1087   4830.530830  11353.22760
# 283   11295.519732  11879.10405
# 790    4385.290780   5662.22500
# 594    6362.502200   5709.16440
# ...            ...          ...
# 954   21952.579030  20009.63365
# 1038   7905.439640   2250.83520
# 1264  12705.250732  10370.91255
# 375   28034.856336  18033.96790
# 798    4410.802000  11848.14100
#
# [335 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2_nomulti,y_pred2)
# Out:
# 0.5401754834852075

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test2_nomulti,y_pred2)
# Out:
# 5628.10815400597

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test2_nomulti,y_pred2)
# Out:
# 58989172.75122999

# %%
mse = mean_squared_error(y_test2_nomulti, y_pred2)
rmse = np.sqrt(mse)
rmse
# Out:
# 7680.440921667843

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test2_nomulti, y_pred2)
print(mape)
mape = mape * 100
mape
# Out:
# 0.8490407204938833
# 84.90407204938833

# %% [markdown]
# 70-30

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train3_nomulti,y_train3_nomulti)
# Out:
# KNeighborsRegressor()

# %%
y_pred3 = model.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [24867.142956  3920.46256   6666.30452   7801.18765   2987.15156
#  12587.681818  2987.15156   9430.74429  10499.63022  38549.09783
#   7801.18765  11393.838508  3920.46256  15994.73927   2987.15156
#   3920.46256   3920.46256  39189.96108   8276.101626 11393.838508
#  10499.63022   9203.516834 10499.63022   7002.8924   12910.416712
#  36444.18036   9046.14891  27066.26655  12814.31377   8607.78908
#   5545.31358   7801.18765   5545.31358  16828.602956  7801.18765
#   7862.3238   34785.05424   7801.18765   5545.31358   6754.50827
#  35329.3157    6208.1664   13531.261892 34785.05424   9126.837666
#   8607.78908   9930.25864  12587.681818 10499.63022   9126.837666
#   2987.15156   8276.101626  9126.837666  9930.25864   9203.516834
#   9126.837666 10499.63022  10499.63022   7002.8924    9126.837666
#   6208.1664    7801.18765   9126.837666  9149.19765   6666.30452
#   5545.31358   9203.516834 21020.52906  12587.681818  2987.15156
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3_nomulti})
print(df)
# Out:
#          Predicted       Actual
# 629   24867.142956  42983.45850
# 1087   3920.462560  11353.22760
# 283    6666.304520  11879.10405
# 790    7801.187650   5662.22500
# 594    2987.151560   5709.16440
# ...            ...          ...
# 924    9126.837666   6250.43500
# 873    6208.166400   6849.02600
# 731    6208.166400  10065.41300
# 363   11186.709914   2597.77900
# 10     8607.789080   2721.32080
#
# [402 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3_nomulti,y_pred3)
# Out:
# 0.5591798213342579

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test3_nomulti,y_pred3)
# Out:
# 5723.503380288557

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test3_nomulti,y_pred3)
# Out:
# 60381376.55397289

# %%
mse = mean_squared_error(y_test3_nomulti, y_pred3)
rmse = np.sqrt(mse)
rmse
# Out:
# 7770.545447648633

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test3_nomulti, y_pred3)
print(mape)
mape = mape * 100
mape
# Out:
# 0.9206350731127811
# 92.06350731127812

# %% [markdown]
# 60-40

# %%
model=KNeighborsRegressor(n_neighbors=5)
model.fit(X_train4_nomulti,y_train4_nomulti)
# Out:
# KNeighborsRegressor()

# %%
y_pred4 = model.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [28514.476758  7667.0452   10670.094332  4388.9599    5140.02136
#   4941.55957   5140.02136   8756.67939   6189.8663   32851.50177
#   4388.9599   12073.409628  7667.0452   12093.168988  5140.02136
#   7667.0452    7667.0452   35846.09015  13825.977606 12073.409628
#   6189.8663   10338.771     6189.8663    6936.2494   13977.851352
#  41453.40604   8617.26951  20355.32803   7466.50119  10312.97619
#   8212.29346   4388.9599    8212.29346  12520.68305   4388.9599
#   5825.01744  41404.061278  4388.9599    8212.29346   8381.0374
#  35520.88759   7421.1538   11573.748932 41404.061278 15500.061312
#  10312.97619  10299.00532   4941.55957   6189.8663   15500.061312
#   5140.02136  13825.977606 15500.061312 10299.00532  10338.771
#  15500.061312  6189.8663    6189.8663    6936.2494   15500.061312
#   7421.1538    4388.9599   15500.061312 18912.154412 10670.094332
#   8212.29346  10338.771    19639.70918   4941.55957   5140.02136
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4_nomulti})
print(df)
# Out:
#          Predicted       Actual
# 629   28514.476758  42983.45850
# 1087   7667.045200  11353.22760
# 283   10670.094332  11879.10405
# 790    4388.959900   5662.22500
# 594    5140.021360   5709.16440
# ...            ...          ...
# 479    5140.021360   1824.28540
# 538    9321.238862   8233.09750
# 117   29175.769142  19107.77960
# 5      4388.959900   3756.62160
# 1250  31661.534250  18648.42170
#
# [535 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4_nomulti,y_pred4)
# Out:
# 0.4931006058785118

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test4_nomulti,y_pred4)
# Out:
# 6018.831347297197

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test4_nomulti,y_pred4)
# Out:
# 67709584.7755217

# %%
mse = mean_squared_error(y_test4_nomulti, y_pred4)
rmse = np.sqrt(mse)
rmse
# Out:
# 8228.583400289608

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test4_nomulti, y_pred4)
print(mape)
mape = mape * 100
mape
# Out:
# 0.9650568253295947
# 96.50568253295947

# %% [markdown]
# **Support Vector Machine after VIF**

# %%
from sklearn.svm import SVR

# %% [markdown]
# 80-20

# %%
model = SVR(kernel='rbf')
model.fit(X_train1_nomulti, y_train1_nomulti)
# Out:
# SVR()

# %%
y_pred1 = model.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [9639.80011528 9589.84324727 9582.14776998 9587.75037203 9587.94542744
#  9590.7152809  9587.94542744 9616.82202997 9590.83605707 9644.28191313
#  9587.75037203 9612.63021919 9589.84324727 9596.7049     9587.94542744
#  9589.84324727 9589.84324727 9642.69289581 9597.48607395 9612.63021919
#  9590.83605707 9594.04096773 9590.83605707 9594.27191885 9593.98891615
#  9642.24016252 9611.1828358  9646.37347366 9583.89329952 9591.38848701
#  9594.62075491 9587.75037203 9594.62075491 9622.06439053 9587.75037203
#  9578.44725918 9645.59501414 9587.75037203 9594.62075491 9620.70776282
#  9646.49097696 9585.26986214 9617.02876193 9645.59501414 9595.8055645
#  9591.38848701 9618.71957482 9590.7152809  9590.83605707 9595.8055645
#  9587.94542744 9597.48607395 9595.8055645  9618.71957482 9594.04096773
#  9595.8055645  9590.83605707 9590.83605707 9594.27191885 9595.8055645
#  9585.26986214 9587.75037203 9595.8055645  9599.18198847 9582.14776998
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred1,'Actual':y_test1_nomulti})
print(df)
# Out:
#         Predicted       Actual
# 629   9639.800115  42983.45850
# 1087  9589.843247  11353.22760
# 283   9582.147770  11879.10405
# 790   9587.750372   5662.22500
# 594   9587.945427   5709.16440
# ...           ...          ...
# 1164  9583.893300   7153.55390
# 962   9578.927404  14474.67500
# 1158  9590.715281   2459.72010
# 1241  9642.240163  49577.66240
# 216   9590.836057  10355.64100
#
# [268 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test1_nomulti,y_pred1)
# Out:
# -0.037442055410901176

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test1_nomulti,y_pred1)
# Out:
# 7450.92588600011

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test1_nomulti,y_pred1)
# Out:
# 134203320.8723334

# %%
mse = mean_squared_error(y_test1_nomulti, y_pred1)
rmse = np.sqrt(mse)
rmse
# Out:
# 11584.61569808569

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test1_nomulti, y_pred1)
print(mape)
mape = mape * 100
mape
# Out:
# 1.1426275913316346
# 114.26275913316346

# %% [markdown]
# 75-25

# %%
model = SVR(kernel='rbf')
model.fit(X_train2_nomulti, y_train2_nomulti)
# Out:
# SVR()

# %%
y_pred2 = model.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [9611.34895306 9565.01927937 9559.62552005 9561.98184158 9562.99617279
#  9565.35022441 9562.99617279 9589.22325796 9565.7571376  9615.00859239
#  9561.98184158 9584.94296226 9565.01927937 9573.03046521 9562.99617279
#  9565.01927937 9565.01927937 9613.5783928  9572.9403973  9584.94296226
#  9565.7571376  9566.43482337 9565.7571376  9570.59850098 9570.75723564
#  9614.87775069 9584.40734681 9619.1877366  9561.3570232  9566.76078374
#  9569.59231235 9561.98184158 9569.59231235 9593.02105042 9561.98184158
#  9555.79709968 9615.83348903 9561.98184158 9569.59231235 9591.57787175
#  9616.86780675 9561.10902843 9588.65205175 9615.83348903 9568.68180898
#  9566.76078374 9591.32211912 9565.35022441 9565.7571376  9568.68180898
#  9562.99617279 9572.9403973  9568.68180898 9591.32211912 9566.43482337
#  9568.68180898 9565.7571376  9565.7571376  9570.59850098 9568.68180898
#  9561.10902843 9561.98184158 9568.68180898 9575.54567785 9559.62552005
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred2,'Actual':y_test2_nomulti})
print(df)
# Out:
#         Predicted       Actual
# 629   9611.348953  42983.45850
# 1087  9565.019279  11353.22760
# 283   9559.625520  11879.10405
# 790   9561.981842   5662.22500
# 594   9562.996173   5709.16440
# ...           ...          ...
# 954   9612.705067  20009.63365
# 1038  9566.760784   2250.83520
# 1264  9573.030465  10370.91255
# 375   9611.348953  18033.96790
# 798   9566.434823  11848.14100
#
# [335 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test2_nomulti,y_pred2)
# Out:
# -0.045222735755120036

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test2_nomulti,y_pred2)
# Out:
# 7454.3319915343955

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test2_nomulti,y_pred2)
# Out:
# 134087727.61899592

# %%
mse = mean_squared_error(y_test2_nomulti, y_pred2)
rmse = np.sqrt(mse)
rmse
# Out:
# 11579.625538807199

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test2_nomulti, y_pred2)
print(mape)
mape = mape * 100
mape
# Out:
# 1.0949347145852855
# 109.49347145852855

# %% [markdown]
# 70-30

# %%
model = SVR(kernel='rbf')
model.fit(X_train3_nomulti, y_train3_nomulti)
# Out:
# SVR()

# %%
y_pred3 = model.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [9644.13636573 9600.87757867 9598.08624052 9599.27623679 9599.76734243
#  9603.78497812 9599.76734243 9623.64474854 9601.56575059 9647.03755296
#  9599.27623679 9617.29778441 9600.87757867 9609.53153549 9599.76734243
#  9600.87757867 9600.87757867 9645.03220204 9611.29727572 9617.29778441
#  9601.56575059 9606.70161099 9601.56575059 9608.37324208 9604.7427627
#  9646.10701286 9618.67479537 9653.12599521 9596.61641425 9604.70705292
#  9603.79481979 9599.27623679 9603.79481979 9626.40015036 9599.27623679
#  9592.21197975 9651.21952259 9599.27623679 9603.79481979 9625.18908087
#  9649.08644808 9600.87516303 9620.72116718 9651.21952259 9607.96669274
#  9604.70705292 9624.71790719 9603.78497812 9601.56575059 9607.96669274
#  9599.76734243 9611.29727572 9607.96669274 9624.71790719 9606.70161099
#  9607.96669274 9601.56575059 9601.56575059 9608.37324208 9607.96669274
#  9600.87516303 9599.27623679 9607.96669274 9609.65783305 9598.08624052
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred3,'Actual':y_test3_nomulti})
print(df)
# Out:
#         Predicted       Actual
# 629   9644.136366  42983.45850
# 1087  9600.877579  11353.22760
# 283   9598.086241  11879.10405
# 790   9599.276237   5662.22500
# 594   9599.767342   5709.16440
# ...           ...          ...
# 924   9607.966693   6250.43500
# 873   9600.875163   6849.02600
# 731   9600.875163  10065.41300
# 363   9601.308913   2597.77900
# 10    9604.707053   2721.32080
#
# [402 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test3_nomulti,y_pred3)
# Out:
# -0.05529074140055812

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test3_nomulti,y_pred3)
# Out:
# 7781.744636513323

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test3_nomulti,y_pred3)
# Out:
# 144548527.30039117

# %%
mse = mean_squared_error(y_test3_nomulti, y_pred3)
rmse = np.sqrt(mse)
rmse
# Out:
# 12022.833580333347

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test3_nomulti, y_pred3)
print(mape)
mape = mape * 100
mape
# Out:
# 1.0787561121252645
# 107.87561121252645

# %% [markdown]
# 60-40

# %%
model = SVR(kernel='rbf')
model.fit(X_train4_nomulti, y_train4_nomulti)
# Out:
# SVR()

# %%
y_pred4 = model.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [9715.09699269 9678.21534673 9677.22172722 9679.76593217 9679.59685824
#  9681.24700758 9679.59685824 9697.76606963 9678.32190855 9718.70687322
#  9679.76593217 9693.37381162 9678.21534673 9686.78577326 9679.59685824
#  9678.21534673 9678.21534673 9716.81988913 9687.57530838 9693.37381162
#  9678.32190855 9682.02263033 9678.32190855 9683.23193506 9680.97978866
#  9720.07676403 9692.33401506 9724.56778344 9675.11888043 9681.83567855
#  9683.949167   9679.76593217 9683.949167   9699.30484307 9679.76593217
#  9672.9281637  9720.42025879 9679.76593217 9683.949167   9698.45953474
#  9721.21551148 9677.04536912 9697.07857239 9720.42025879 9683.34828314
#  9681.83567855 9698.81056665 9681.24700758 9678.32190855 9683.34828314
#  9679.59685824 9687.57530838 9683.34828314 9698.81056665 9682.02263033
#  9683.34828314 9678.32190855 9678.32190855 9683.23193506 9683.34828314
#  9677.04536912 9679.76593217 9683.34828314 9686.62552763 9677.22172722
# ...

# %%
df=pd.DataFrame({'Predicted':y_pred4,'Actual':y_test4_nomulti})
print(df)
# Out:
#         Predicted       Actual
# 629   9715.096993  42983.45850
# 1087  9678.215347  11353.22760
# 283   9677.221727  11879.10405
# 790   9679.765932   5662.22500
# 594   9679.596858   5709.16440
# ...           ...          ...
# 479   9679.596858   1824.28540
# 538   9674.306105   8233.09750
# 117   9719.936217  19107.77960
# 5     9679.765932   3756.62160
# 1250  9725.597870  18648.42170
#
# [535 rows x 2 columns]

# %%
from sklearn.metrics import r2_score
r2_score(y_test4_nomulti,y_pred4)
# Out:
# -0.052911941147946395

# %%
from sklearn import metrics
metrics.mean_absolute_error(y_test4_nomulti,y_pred4)
# Out:
# 7778.463749640746

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test4_nomulti,y_pred4)
# Out:
# 140643747.39266196

# %%
mse = mean_squared_error(y_test4_nomulti, y_pred4)
rmse = np.sqrt(mse)
rmse
# Out:
# 11859.331658768211

# %%
from sklearn.metrics import mean_absolute_percentage_error
mape = mean_absolute_percentage_error(y_test4_nomulti, y_pred4)
print(mape)
mape = mape * 100
mape
# Out:
# 1.098752698075313
# 109.87526980753131

# %% [markdown]
# **Decision Tree Regressor after VIF**

# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %% [markdown]
# 80-20

# %%
clf = DecisionTreeRegressor()
clf1 = clf.fit(X_train1_nomulti,y_train1_nomulti)
print(clf1)
# Out:
# DecisionTreeRegressor()

# %%
y_pred1 = clf.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [28323.28984429  6881.55251278 10897.72765714  8307.20887316
#   6099.3485451   8262.40049076  6099.3485451   8503.28629375
#   7778.04474116 40521.214825    8307.20887316 10583.839105
#   6881.55251278 12375.19349429  6099.3485451   6881.55251278
#   6881.55251278 38688.0815075  10710.477385   10583.839105
#   7778.04474116  7522.78149896  7778.04474116  7301.69130769
#  10058.6357913  39298.88283333  6779.67768462 31790.90439778
#   8981.07047333  7639.48006958  7185.20618125  8307.20887316
#   7185.20618125  6520.34865     8307.20887316  7816.80772
#  32138.8123825   8307.20887316  7185.20618125  5857.258925
#  30673.98505     6809.82386556 13044.714092   32138.8123825
#   8964.135313    7639.48006958 10314.68341937  8262.40049076
#   7778.04474116  8964.135313    6099.3485451  10710.477385
#   8964.135313   10314.68341937  7522.78149896  8964.135313
#   7778.04474116  7778.04474116  7301.69130769  8964.135313
#   6809.82386556  8307.20887316  8964.135313   11654.39865
# ...

# %%
print("R-squared:", metrics.r2_score(y_test1_nomulti, y_pred1))
# Out:
# R-squared: 0.6354908195618768

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test1_nomulti, y_pred1))
# Out:
# Mean Squared Error: 47152843.13770524

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test1_nomulti, y_pred1))
# Out:
# Mean Absolute Error: 5126.588029631648

# %% [markdown]
# 75-25

# %%
clf = DecisionTreeRegressor()
clf2 = clf.fit(X_train2_nomulti,y_train2_nomulti)
print(clf2)
# Out:
# DecisionTreeRegressor()

# %%
y_pred2 = clf.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [30061.96531     7014.65988515 11742.08580588  8349.77987294
#   6099.3485451   8150.73277769  6099.3485451   8503.28629375
#   7858.612088   40829.1507      8349.77987294 10107.26999143
#   7014.65988515 12475.4075415   6099.3485451   7014.65988515
#   7014.65988515 35640.46472714 10710.477385   10107.26999143
#   7858.612088    7328.29843023  7858.612088    7602.37991667
#  10198.26937273 39298.88283333  6782.268225   30599.89581143
#   8981.07047333  7754.13208809  6982.00237857  8349.77987294
#   6982.00237857  6520.34865     8349.77987294  8274.26650083
#  33501.639559    8349.77987294  6982.00237857  5857.258925
#  30673.98505     6809.82386556 13106.81555778 33501.639559
#   8563.13754231  7754.13208809 10314.68341938  8150.73277769
#   7858.612088    8563.13754231  6099.3485451  10710.477385
#   8563.13754231 10314.68341938  7328.29843023  8563.13754231
#   7858.612088    7858.612088    7602.37991667  8563.13754231
# ...

# %%
print("R-squared:", metrics.r2_score(y_test2_nomulti, y_pred2))
# Out:
# R-squared: 0.6064141864500537

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test2_nomulti, y_pred2))
# Out:
# Mean Squared Error: 50491656.52128571

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test2_nomulti, y_pred2))
# Out:
# Mean Absolute Error: 5346.590258896408

# %% [markdown]
# 70-30

# %%
clf = DecisionTreeRegressor()
clf3 = clf.fit(X_train3_nomulti,y_train3_nomulti)
print(clf3)
# Out:
# DecisionTreeRegressor()

# %%
y_pred3 = clf.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [29766.91208364  7155.01895969 11463.59047071  8541.57464788
#   5889.00997848  8218.47447858  5889.00997848  8914.6775
#   7837.10485472 40829.1507      8541.57464788 10107.26999143
#   7155.01895969 12635.53818579  5889.00997848  7155.01895969
#   7155.01895969 36115.96575    10710.477385   10107.26999143
#   7837.10485472  7417.15271951  7837.10485472  7758.9589
#  10198.26937273 39695.671475    6905.31736364 25938.0327
#   9293.6186045   7961.40864024  6982.00237857  8541.57464788
#   6982.00237857  4877.98105     8541.57464788  8456.86705739
#  33501.639559    8541.57464788  6982.00237857  5857.258925
#  30673.98505     6431.68510304 12399.38570857 33501.639559
#   8623.99813553  7961.40864024 10314.68341938  8218.47447858
#   7837.10485472  8623.99813553  5889.00997848 10710.477385
#   8623.99813553 10314.68341938  7417.15271951  8623.99813553
#   7837.10485472  7837.10485472  7758.9589      8623.99813553
#   6431.68510304  8541.57464788  8623.99813553 12050.36822353
# ...

# %%
print("R-squared:", metrics.r2_score(y_test3_nomulti, y_pred3))
# Out:
# R-squared: 0.6153072951841037

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test3_nomulti, y_pred3))
# Out:
# Mean Squared Error: 52693311.67498149

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test3_nomulti, y_pred3))
# Out:
# Mean Absolute Error: 5388.69226405593

# %% [markdown]
# 60-40

# %%
clf = DecisionTreeRegressor()
clf4 = clf.fit(X_train4_nomulti,y_train4_nomulti)
print(clf4)
# Out:
# DecisionTreeRegressor()

# %%
y_pred4 = clf.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
print("R-squared:", metrics.r2_score(y_test4_nomulti, y_pred4))
# Out:
# R-squared: 0.5728947438630415

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test4_nomulti, y_pred4))
# Out:
# Mean Squared Error: 57051004.36862087

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test4_nomulti, y_pred4))
# Out:
# Mean Absolute Error: 5583.305559159157

# %% [markdown]
# **Random Forest after VIF**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.tree import plot_tree

from matplotlib import pyplot as plt

# %% [markdown]
# 80-20

# %%
print(X_train1_nomulti.shape)
print(y_train1_nomulti.shape)
print(X_test1_nomulti.shape)
print(y_test1_nomulti.shape)
# Out:
# (1069, 6)
# (1069,)
# (268, 6)
# (268,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train1_nomulti, y_train1_nomulti)
# Out:
# RandomForestRegressor()

# %%
y_pred1 = clf.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
print("R-squared:", metrics.r2_score(y_test1_nomulti, y_pred1))
# Out:
# R-squared: 0.6379989828484005

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test1_nomulti, y_pred1))
# Out:
# Mean Squared Error: 46828387.57839381

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test1_nomulti, y_pred1))
# Out:
# Mean Absolute Error: 5080.645174457514

# %% [markdown]
# 75-25

# %%
print(X_train2_nomulti.shape)
print(y_train2_nomulti.shape)
print(X_test2_nomulti.shape)
print(y_test2_nomulti.shape)
# Out:
# (1002, 6)
# (1002,)
# (335, 6)
# (335,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train2_nomulti, y_train2_nomulti)
# Out:
# RandomForestRegressor()

# %%
y_pred2 = clf.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
print("R-squared:", metrics.r2_score(y_test2_nomulti, y_pred2))
# Out:
# R-squared: 0.5926276261898297

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test2_nomulti, y_pred2))
# Out:
# Mean Squared Error: 52260282.933377944

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test2_nomulti, y_pred2))
# Out:
# Mean Absolute Error: 5367.993351642921

# %% [markdown]
# 70-30

# %%
print(X_train3_nomulti.shape)
print(y_train3_nomulti.shape)
print(X_test3_nomulti.shape)
print(y_test3_nomulti.shape)
# Out:
# (935, 6)
# (935,)
# (402, 6)
# (402,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train3_nomulti, y_train3_nomulti)
# Out:
# RandomForestRegressor()

# %%
y_pred3 = clf.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
print("R-squared:", metrics.r2_score(y_test3_nomulti, y_pred3))
# Out:
# R-squared: 0.6061361817349047

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test3_nomulti, y_pred3))
# Out:
# Mean Squared Error: 53949525.61752695

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test3_nomulti, y_pred3))
# Out:
# Mean Absolute Error: 5417.700701440971

# %% [markdown]
# 60-40

# %%
print(X_train4_nomulti.shape)
print(y_train4_nomulti.shape)
print(X_test4_nomulti.shape)
print(y_test4_nomulti.shape)
# Out:
# (802, 6)
# (802,)
# (535, 6)
# (535,)

# %%
rf = RandomForestRegressor()
rf.fit(X_train4_nomulti, y_train4_nomulti)
# Out:
# RandomForestRegressor()

# %%
y_pred4 = clf.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
print("R-squared:", metrics.r2_score(y_test4_nomulti, y_pred4))
# Out:
# R-squared: 0.5728947438630415

# %%
print("Mean Squared Error:", metrics.mean_squared_error(y_test4_nomulti, y_pred4))
# Out:
# Mean Squared Error: 57051004.36862087

# %%
print("Mean Absolute Error:", metrics.mean_absolute_error(y_test4_nomulti, y_pred4))
# Out:
# Mean Absolute Error: 5583.305559159157

# %% [markdown]
# **XGBOOST after VIF**

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score,mean_absolute_error

# %% [markdown]
# 80-20

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train1_nomulti, y_train1_nomulti)

# %%
y_pred1 = clf.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
mse = mean_squared_error(y_test1_nomulti, y_pred1)
r2 = r2_score(y_test1_nomulti, y_pred1)
mae = mean_absolute_error(y_test1_nomulti, y_pred1)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 46828387.57839381
# R-squared: 0.6379989828484005
# Mean Absolute Error: 5080.645174457514

# %% [markdown]
# 75-25

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train2_nomulti, y_train2_nomulti)

# %%
y_pred2 = clf.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
mse = mean_squared_error(y_test2_nomulti, y_pred2)
r2 = r2_score(y_test2_nomulti, y_pred2)
mae = mean_absolute_error(y_test2_nomulti, y_pred2)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 52260282.933377944
# R-squared: 0.5926276261898297
# Mean Absolute Error: 5367.993351642921

# %% [markdown]
# 70-30

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train3_nomulti, y_train3_nomulti)

# %%
y_pred3 = clf.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
mse = mean_squared_error(y_test3_nomulti, y_pred3)
r2 = r2_score(y_test3_nomulti, y_pred3)
mae = mean_absolute_error(y_test3_nomulti, y_pred3)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 53949525.61752695
# R-squared: 0.6061361817349047
# Mean Absolute Error: 5417.700701440971

# %% [markdown]
# 60-40

# %%
model = xgb.XGBRegressor()
model = model.fit(X_train4_nomulti, y_train4_nomulti)

# %%
y_pred4 = clf.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
mse = mean_squared_error(y_test4_nomulti, y_pred4)
r2 = r2_score(y_test4_nomulti, y_pred4)
mae = mean_absolute_error(y_test4_nomulti, y_pred4)

print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
print(f"Mean Absolute Error: {mae}")
# Out:
# Mean Squared Error: 57051004.36862087
# R-squared: 0.5728947438630415
# Mean Absolute Error: 5583.305559159157

# %% [markdown]
# **ADABOOST after VIF**

# %%
import pandas as pd
import seaborn as sns
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.ensemble import AdaBoostRegressor
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# 80-20

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train1_nomulti, y_train1_nomulti)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred1 = clf.predict(X_test1_nomulti)
print(y_pred1)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
r2 = r2_score(y_test1_nomulti, y_pred1)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test1_nomulti, y_pred1)
print(f"Mean Squared Error: {mse:.2f}")

mae = mean_absolute_error(y_test1_nomulti, y_pred1)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.64
# Mean Squared Error: 46828387.58
# Mean Absolute Error: 5080.65

# %% [markdown]
# 75-25

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train2_nomulti, y_train2_nomulti)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred2 = clf.predict(X_test2_nomulti)
print(y_pred2)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
r2 = r2_score(y_test2_nomulti, y_pred2)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test2_nomulti, y_pred2)
print(f"Mean Squared Error: {mse:.2f}")

mae = mean_absolute_error(y_test2_nomulti, y_pred2)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.59
# Mean Squared Error: 52260282.93
# Mean Absolute Error: 5367.99

# %% [markdown]
# 70-30

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train3_nomulti, y_train3_nomulti)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred3 = clf.predict(X_test3_nomulti)
print(y_pred3)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
r2 = r2_score(y_test3_nomulti, y_pred3)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test3_nomulti, y_pred3)
print(f"Mean Squared Error: {mse:.2f}")

mae = mean_absolute_error(y_test3_nomulti, y_pred3)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.61
# Mean Squared Error: 53949525.62
# Mean Absolute Error: 5417.70

# %% [markdown]
# 60-40

# %%
model = AdaBoostRegressor(n_estimators=50, random_state=42)
model.fit(X_train4_nomulti, y_train4_nomulti)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
y_pred4 = clf.predict(X_test4_nomulti)
print(y_pred4)
# Out:
# [29053.729984    7786.68412435 13598.272974    9222.04718444
#   6168.16935605  7683.05336457  6168.16935605  8756.67939
#   7590.33700067 40829.1507      9222.04718444 12073.409628
#   7786.68412435 12084.96107471  6168.16935605  7786.68412435
#   7786.68412435 35846.09015    10727.02400231 12073.409628
#   7590.33700067  7316.41094939  7590.33700067  7972.5065
#   9830.5379305  42685.3763      6905.31736364 23238.1636
#   9295.94088895  8010.92828467  7494.83403333  9222.04718444
#   7494.83403333  4877.98105     9222.04718444  8144.83974381
#  35066.02634143  9222.04718444  7494.83403333  5857.258925
#  30673.98505     6438.47828955 15487.37478667 35066.02634143
#   8776.13049438  8010.92828467 10314.68341938  7683.05336457
#   7590.33700067  8776.13049438  6168.16935605 10727.02400231
#   8776.13049438 10314.68341938  7316.41094939  8776.13049438
#   7590.33700067  7590.33700067  7972.5065      8776.13049438
#   6438.47828955  9222.04718444  8776.13049438 13735.7464
# ...

# %%
r2 = r2_score(y_test4_nomulti, y_pred4)
print(f"R-squared: {r2:.2f}")

mse = mean_squared_error(y_test4_nomulti, y_pred4)
print(f"Mean Squared Error: {mse:.2f}")

mae = mean_absolute_error(y_test4_nomulti, y_pred4)
print(f"Mean Absolute Error: {mae:.2f}")
# Out:
# R-squared: 0.57
# Mean Squared Error: 57051004.37
# Mean Absolute Error: 5583.31

# %% [markdown]
# **Neural Network**

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, test_size=0.20, train_size=0.80,random_state=1)
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, test_size=0.25, train_size=0.75,random_state=1)
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, test_size=0.30, train_size=0.70,random_state=1)
X_train4, X_test4, y_train4, y_test4 = train_test_split(X, y, test_size=0.40, train_size=0.60,random_state=1)

# %% [markdown]
# 80-20

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model_nom1= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),

                            tf.keras.layers.Dense(8),

                            tf.keras.layers.Dense(6),



                            tf.keras.layers.Dense(4),

                            tf.keras.layers.Dense(2),


                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model_nom1.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate =0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model_nom1.fit(X_train1, y_train1, epochs= 400, verbose=1)
# Out:
# Epoch 1/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 13726.9219 - mae: 13726.9219
# Epoch 2/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13690.5410 - mae: 13690.5410
# Epoch 3/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13599.2920 - mae: 13599.2920
# Epoch 4/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13294.7578 - mae: 13294.7578
# Epoch 5/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 12337.3398 - mae: 12337.3398
# Epoch 6/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9927.0752 - mae: 9927.0752
# Epoch 7/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7763.0259 - mae: 7763.0259
# Epoch 8/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7705.7085 - mae: 7705.7085
# Epoch 9/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7680.0835 - mae: 7680.0835
# Epoch 10/400
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7656.6211 - mae: 7656.6211
# Epoch 11/400
# ...

# %%
model_nom1.evaluate(X_test1, y_test1)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2702.3647 - mae: 2702.3647
# [2667.74853515625, 2667.74853515625]

# %%
model_nom1.summary();
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_54 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_55 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_56 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_57 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 75-25

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model_nom2= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),


                            tf.keras.layers.Dense(8),

                            tf.keras.layers.Dense(6),



                            tf.keras.layers.Dense(4),

                            tf.keras.layers.Dense(2),


                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model_nom2.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model_nom2.fit(X_train2, y_train2, epochs= 500, verbose=1)
# Out:
# Epoch 1/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 13685.7686 - mae: 13685.7686
# Epoch 2/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13600.0674 - mae: 13600.0674
# Epoch 3/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13409.9844 - mae: 13409.9844
# Epoch 4/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 12883.7832 - mae: 12883.7832
# Epoch 5/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11507.2715 - mae: 11507.2715
# Epoch 6/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8981.1768 - mae: 8981.1768
# Epoch 7/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7741.8447 - mae: 7741.8447
# Epoch 8/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7708.9766 - mae: 7708.9766
# Epoch 9/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7685.9336 - mae: 7685.9336
# Epoch 10/500
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7668.1367 - mae: 7668.1367
# Epoch 11/500
# ...

# %%
model_nom2.evaluate(X_test2, y_test2)
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2678.4839 - mae: 2678.4839
# [2932.37939453125, 2932.37939453125]

# %%
model_nom2.summary();
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_66 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_67 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_68 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_69 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 70-30

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model_nom3= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),


                            tf.keras.layers.Dense(8),

                            tf.keras.layers.Dense(6),



                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),


                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model_nom3.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model_nom3.fit(X_train3, y_train3, epochs= 250, verbose=1)
# Out:
# Epoch 1/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 13405.5752 - mae: 13405.5752
# Epoch 2/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13368.4688 - mae: 13368.4688
# Epoch 3/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13253.8408 - mae: 13253.8408
# Epoch 4/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12908.1533 - mae: 12908.1533
# Epoch 5/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11951.1387 - mae: 11951.1387
# Epoch 6/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9812.6934 - mae: 9812.6934
# Epoch 7/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7624.1997 - mae: 7624.1997
# Epoch 8/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7447.2241 - mae: 7447.2241
# Epoch 9/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7418.9619 - mae: 7418.9619
# Epoch 10/250
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7393.9136 - mae: 7393.9136
# Epoch 11/250
# ...

# %%
model_nom3.evaluate(X_test3, y_test3)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2714.4573 - mae: 2714.4573
# [2958.77587890625, 2958.77587890625]

# %%
model_nom3.summary();
# Out:
# Model: "sequential_12"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_72 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_73 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_74 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_75 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# 60-40

# %%
tf.random.set_seed(42)

# STEP1: Creating the model

model_nom4= tf.keras.Sequential([
                            tf.keras.layers.Dense(16),

                            tf.keras.layers.Dense(8),

                            tf.keras.layers.Dense(6),

                            tf.keras.layers.Dense(4),


                            tf.keras.layers.Dense(2),


                            tf.keras.layers.Dense(1)
])

# STEP2: Compiling the model

model_nom4.compile(loss= tf.keras.losses.mae,
              optimizer= tf.keras.optimizers.Adam(learning_rate=0.001),  #SGD
              metrics= ["mae"])

# STEP3: Fit the model

history= model_nom4.fit(X_train4, y_train4, epochs= 600, verbose=1)
# Out:
# Epoch 1/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - loss: 13610.6660 - mae: 13610.6660
# Epoch 2/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13565.9580 - mae: 13565.9580
# Epoch 3/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 13473.7852 - mae: 13473.7852
# Epoch 4/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 13256.1211 - mae: 13256.1211
# Epoch 5/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 12742.1162 - mae: 12742.1162
# Epoch 6/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11614.5273 - mae: 11614.5273
# Epoch 7/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9645.1074 - mae: 9645.1074
# Epoch 8/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7815.0405 - mae: 7815.0405
# Epoch 9/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7607.1978 - mae: 7607.1978
# Epoch 10/600
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7572.6963 - mae: 7572.6963
# Epoch 11/600
# ...

# %%
model_nom4.evaluate(X_test4, y_test4)
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2818.1421 - mae: 2818.1421
# [3088.9296875, 3088.9296875]

# %%
model_nom4.summary();
# Out:
# Model: "sequential_15"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_90 (Dense)                     │ (None, 16)                  │             144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_91 (Dense)                     │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_92 (Dense)                     │ (None, 6)                   │              54 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_93 (Dense)                     │ (None, 4)                   │              28 │
# ...

# %%
pd.DataFrame(history.history).plot()
plt.ylabel("loss")
plt.xlabel("epochs")
# Out:
# Text(0.5, 0, 'epochs')
